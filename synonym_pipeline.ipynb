# %% [markdown]
# <a href="https://colab.research.google.com/github/mnbpdx/code_switched_next_word_predictor/blob/main/synonym_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Steps, from [Refined Project Proposal](https://docs.google.com/document/d/1NRUdfsiXkgPQW7Mg-CSVs8FDzghQjYWcvZ9JPUFfLW4/edit?usp=sharing)
#
# 1. Pass the predicted next word to a pre-trained language recognition model to **determine the language** of the word (one of the two languages in our mixed, code-switched corpus.)
# 2. **Translate** the predicted next word into the other language by passing it into an appropriate translation model.
# 3. **Get n synonyms** of predicted next word in both languages using cosine distance between word embeddings, gathered from two vector embedding models, one in each language. This could also be done by a GPT-3 model.
# 4. **Score the model** based on whether or not the actual next word is in the list of predicted next word bilingual synonyms.

# %% [markdown]
# # Full Synonym Pipeline

# %% [markdown]
# ## Imports/Downloads

# %%
# !pip install -U easynmt
# !pip install sacremoses # was told to install this by a warning

from easynmt import EasyNMT
import nltk
from nltk.corpus import wordnet as wn

nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: easynmt in /usr/local/lib/python3.8/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from easynmt) (4.64.1)
# Requirement already satisfied: fasttext in /usr/local/lib/python3.8/dist-packages (from easynmt) (0.9.2)
# Requirement already satisfied: transformers<5,>=4.4 in /usr/local/lib/python3.8/dist-packages (from easynmt) (4.25.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from easynmt) (1.13.0+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from easynmt) (3.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from easynmt) (1.21.6)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.8/dist-packages (from easynmt) (3.19.6)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (from easynmt) (0.1.97)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->easynmt) (4.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (0.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (2022.6.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers<5,>=4.4->easynmt) (3.0.9)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.8/dist-packages (from fasttext->easynmt) (2.10.1)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from fasttext->easynmt) (57.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->easynmt) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->easynmt) (1.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<5,>=4.4->easynmt) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<5,>=4.4->easynmt) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.8/dist-packages (0.0.53)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses) (1.15.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from sacremoses) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sacremoses) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses) (7.1.2)
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# ## Fake Data

# %%
# Fake Data
# predictions = ['pizza', 'turkey', 'baño', 'book', 'manzana', 'tiger']
# actual =    ['whale', 'chicken', 'bathroom', 'libro', 'plátano', 'tiger']

# %% [markdown]
# ## Utility Functions

# %%
# I think I should be raising the exceptions here and catching them in
# the pipeline function actually, but i dont wanna waste time on that rn. 
def langs_are_valid(lang1, lang2):
  if lang1 == lang2:
    print('Langugages must not be the same.')
    return False
  
  if lang1 != 'en' and lang1 != 'es':
    print('Langugage must be either Spanish or English.')
    return False
  
  if lang2 != 'en' and lang2 != 'es':
    print('Langugage must be either Spanish or English.')
    return False

  return True

# %%
def strip_formatting(word: str) -> str:
    word = word.lower()
    word = word.strip()
    word = word.replace('.', '')
    word = word.replace(',', '')
    word = word.replace('-', '')
    word = word.replace('_', '')
    word = word.replace('!', '')
    word = word.replace('?', '')
    return word

# %% [markdown]
# ## Pipeline

# %%
# -- CITE ME -- Look at Mark's scratchpad noteboook for everything we gotta cite
# -- POSSIBLE ISSUE -- 2x check my old comments for issues
# -- POSSIBLE ISSUE -- -- DISCUSSION -- When I run id_model.language_detection on "manzana" it returns 'en'.
# "manzana" IS a word in English, that means like a unit of land or something. That
# wouldn't be a problem (hey, maybe the person speaking Spanglish here DID mean "a unit of land")
# but in this case, it's SO obvious that there's another, much more common Spanish word
# that means "manzana". I feel like the ID model should have caught that, by comparing
# the frequency of the English and Spanish versions. My guess is that this model is
# more used to translating sentences in context rather than words. We can sub it out
# with a different language detection/identification model later then, if we notice this problem at a large scale.
# That shouldn't be hard, there's many. I also wonder if what's happening here is that
# the model is capable of interpreting semi-code-switched sentences and translating them.
# It has to ID them first, so it would interpret an English sentence with a few Spanish words
# as "English", then do the translation step. For that to work, it'd have to have some sense
# of "manzana" as an English word. IOW, could be a NN problem, or a problem of a model that
# is intended to do translation too. Same easy solution though, just sub it out. We
# could even sub it out with an API call to Dictionary.com or something, doesn't
# have to be a NN model.
# Okay now I'm getting different languages detected than English or Spanish. Which
# is a tougher problem to solve. We can switch out the model, but idk if I'm gonna
# be able to find a model that allows us to specify: "Only return one of these
# two languages". The big question is, what do we when our detection model returns
# null, or returns an unknown language? Throw out the prediction from the score?

# -- TODO -- Get rid of all the print statements
# -- TODO -- Make the comments better
# -- TODO -- Dump data to CSV


# -- TODO -- Right now, this function only ACTUALLY works for Spanish and English, gotta
# figure out how to convert from the EasyNMT language strings to the WordNet
# strings. Or I could just hack it. I'm not 100% sure yet that WN works for 
# Mandarin anyway, which would be an issue.
def score_with_synonym_list(predictions, actual, lang1, lang2):
  # if not langs_are_valid(lang1, lang2):
  #   raise Exception('Please use valid EasyNMT language strings.') # idk how to use exceptions in python, someone tell me if this is wrong

  translation_model = EasyNMT('m2m_100_418M')

  synonym_lists = []
  scores = []

  for word in predictions:

    if (lang1 != lang2):
      # Translate word into first language
      word_in_lang1 = translation_model.translate(word, target_lang=lang1)

      # Translate word into the OTHER language
      word_in_lang2 = translation_model.translate(word, target_lang=lang2)
    else:
       word_in_lang1 = word

    if (lang1 == 'en'): # need to update this step to make this function generic with respect to languages
      wn_lang1 = 'eng'
      wn_lang2 = 'spa'
    else:
      wn_lang1 = 'spa'
      wn_lang2 = 'eng'

    # -- POSSIBLE ISSUE -- Should probably limit the number of words, right now there's roughly 0 - 20 for each.
    # Get synonym lists for word and translated_word

    # I'm combining the word and translated_word synonyms, we can split later if needed
    synonyms = []

    # add the words themselves to the synonym list
    synonyms.append(strip_formatting(word_in_lang1))
    if (lang1 != lang2):
      synonyms.append(strip_formatting(word_in_lang2))

    # add synonyms of word in lang1
    for synonym in wn.synsets(word_in_lang1, lang=wn_lang1):
      for item in synonym.lemmas(wn_lang1):
          if item.name() != word_in_lang1:
              unformatted = item.name()
              formatted = strip_formatting(item.name().split('_')[0])
              synonyms.append(formatted)
              print("Unformatted: " + unformatted)
              print("Formatted: " + formatted)

    if (lang1 != lang2):
      # add synonyms of word in lang2
      for synonym in wn.synsets(word_in_lang2, lang=wn_lang2):
        for item in synonym.lemmas(wn_lang2):
            if item.name() != word_in_lang2:
              unformatted = item.name()
              formatted = strip_formatting(item.name().split('_')[0])
              synonyms.append(formatted)
              print("Unformatted: " + unformatted)
              print("Formatted: " + formatted)

    # Throw all the discovered synonyms (and word & translated_word) onto synonym_lists
    synonym_lists.append(synonyms)

  stripped_actual = []

  for a_word in actual:
    stripped_actual.append(strip_formatting(a_word))

  print()
  print()
  print("PREDICTIONS: " + str(predictions))
  print("ACTUAL: " + str(stripped_actual))

  # Compare synonym lists to actual
  match_found = False
  for predicted_word, actual_word, synonyms in zip(predictions, stripped_actual, synonym_lists):
    print()
    print("Predicted: " + predicted_word)
    print("Prediction Synonyms:")
    print(synonyms)
    print("Actual: " + actual_word)
    if actual_word in synonyms:
      match_found = True
      print("!!!!!!!!!MATCH FOUND!!!!!!!!!")
    else:
      match_found = False
    scores.append(match_found)


  # Dump Data to JSON    

  # Calculate and return metric
  return sum(scores) / len(scores)

# %%
# This is just the basic metric, iow, whether or not the predicted word is equal
# to the actual next word.
def score_with_actual_word(predictions, actual):
  scores = []

  for prediction, actual in zip(predictions, actual):
    if prediction == actual:
      scores.append(True)
    else:
      scores.append(False)

  return sum(scores) / len(scores)

# %%
# score_with_synonym_list(predictions, actual, 'en', 'es')

# %%
# score_with_actual_word(predictions, actual)

# %% [markdown]
# ## Score Vince's GPT responses
#
# Uploaded the most recent results manually. We can make this flow better later, by adding this pipeline to the other notebook, or integrating this notebook into the project better.

# %%
import json

standard_results = dict()

standard_results_path = '/content/standard_perfromance.json'
with open(standard_results_path) as json_file:
    standard_results = json.load(json_file)

# pprint(standard_results)

if standard_results:
    print('Standard results loaded')
else:
     print('Standard results not loaded')
# Out:
# Standard results loaded

# %%
prediction_lists = []
actual_lists = []

for corpus in range(3):
  predictions = []
  actual = []
  for input_and_response in standard_results[corpus][1]:
    predictions.append(input_and_response[1][1])
    actual.append(input_and_response[0][4])
  prediction_lists.append(predictions)
  actual_lists.append(actual)

# %%
# # Standard Metric Scores

# scores = []

# for corpus in range(3):
#   scores.append(score_with_actual_word(prediction_lists[corpus], actual_lists[corpus]))

# %%
# Synonym Metric Scores

synonym_scores = []

synonym_scores.append(score_with_synonym_list(prediction_lists[0], actual_lists[0], 'en', 'en'))
synonym_scores.append(score_with_synonym_list(prediction_lists[1], actual_lists[1], 'es', 'es'))
synonym_scores.append(score_with_synonym_list(prediction_lists[2], actual_lists[2], 'en', 'es'))
# Out:
# Unformatted: iodine
# Formatted: iodine
# Unformatted: iodin
# Formatted: iodin
# Unformatted: atomic_number_53
# Formatted: atomic
# Unformatted: one
# Formatted: one
# Unformatted: 1
# Formatted: 1
# Unformatted: ace
# Formatted: ace
# Unformatted: single
# Formatted: single
# Unformatted: unity
# Formatted: unity
# Unformatted: i
# Formatted: i
# Unformatted: one
# Formatted: one
# Unformatted: 1
# Formatted: 1
# Unformatted: i
# Formatted: i
# Unformatted: ane
# Formatted: ane
# Unformatted: bash
# Formatted: bash
# Unformatted: brawl
# Formatted: brawl
# Unformatted: doh
# Formatted: doh
# Unformatted: ut
# Formatted: ut
# Unformatted: Doctor_of_Osteopathy
# Formatted: doctor
# Unformatted: DO
# Formatted: do
# Unformatted: make
# Formatted: make
# Unformatted: perform
# Formatted: perform
# Unformatted: execute
# Formatted: execute
# Unformatted: perform
# Formatted: perform
# Unformatted: fare
# Formatted: fare
# Unformatted: make_out
# Formatted: make
# Unformatted: come
# Formatted: come
# Unformatted: get_along
# Formatted: get
# Unformatted: cause
# Formatted: cause
# Unformatted: make
# Formatted: make
# Unformatted: practice
# Formatted: practice
# Unformatted: practise
# Formatted: practise
# Unformatted: exercise
# Formatted: exercise
# Unformatted: suffice
# Formatted: suffice
# Unformatted: answer
# Formatted: answer
# Unformatted: serve
# Formatted: serve
# Unformatted: make
# Formatted: make
# Unformatted: act
# Formatted: act
# Unformatted: behave
# Formatted: behave
# Unformatted: serve
# Formatted: serve
# Unformatted: manage
# Formatted: manage
# Unformatted: dress
# Formatted: dress
# Unformatted: arrange
# Formatted: arrange
# Unformatted: set
# Formatted: set
# Unformatted: coif
# Formatted: coif
# Unformatted: coiffe
# Formatted: coiffe
# Unformatted: coiffure
# Formatted: coiffure
# Unformatted: beryllium
# Formatted: beryllium
# Unformatted: Be
# Formatted: be
# Unformatted: glucinium
# Formatted: glucinium
# Unformatted: atomic_number_4
# Formatted: atomic
# Unformatted: exist
# Formatted: exist
# Unformatted: equal
# Formatted: equal
# Unformatted: constitute
# Formatted: constitute
# Unformatted: represent
# Formatted: represent
# Unformatted: make_up
# Formatted: make
# Unformatted: comprise
# Formatted: comprise
# Unformatted: follow
# Formatted: follow
# Unformatted: embody
# Formatted: embody
# Unformatted: personify
# Formatted: personify
# Unformatted: live
# Formatted: live
# Unformatted: cost
# Formatted: cost
# Unformatted: mix
# Formatted: mix
# Unformatted: commixture
# Formatted: commixture
# Unformatted: admixture
# Formatted: admixture
# Unformatted: mixture
# Formatted: mixture
# Unformatted: intermixture
# Formatted: intermixture
# Unformatted: blend
# Formatted: blend
# Unformatted: flux
# Formatted: flux
# Unformatted: mix
# Formatted: mix
# Unformatted: conflate
# Formatted: conflate
# Unformatted: commingle
# Formatted: commingle
# Unformatted: immix
# Formatted: immix
# Unformatted: fuse
# Formatted: fuse
# Unformatted: coalesce
# Formatted: coalesce
# Unformatted: meld
# Formatted: meld
# Unformatted: combine
# Formatted: combine
# Unformatted: merge
# Formatted: merge
# Unformatted: desegregate
# Formatted: desegregate
# Unformatted: integrate
# Formatted: integrate
# Unformatted: mix
# Formatted: mix
# Unformatted: mix
# Formatted: mix
# Unformatted: mix
# Formatted: mix
# Unformatted: mix_in
# Formatted: mix
# Unformatted: mix
# Formatted: mix
# Unformatted: mingle
# Formatted: mingle
# Unformatted: commix
# Formatted: commix
# Unformatted: unify
# Formatted: unify
# Unformatted: amalgamate
# Formatted: amalgamate
# Unformatted: shuffle
# Formatted: shuffle
# Unformatted: ruffle
# Formatted: ruffle
# Unformatted: mix
# Formatted: mix
# Unformatted: Lord's_Day
# Formatted: lord's
# Unformatted: Dominicus
# Formatted: dominicus
# Unformatted: Sun
# Formatted: sun
# Unformatted: Billy_Sunday
# Formatted: billy
# Unformatted: William_Ashley_Sunday
# Formatted: william
# Unformatted: Washington
# Formatted: washington
# Unformatted: Evergreen_State
# Formatted: evergreen
# Unformatted: WA
# Formatted: wa
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: exist
# Formatted: exist
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: equal
# Formatted: equal
# Unformatted: be
# Formatted: be
# Unformatted: constitute
# Formatted: constitute
# Unformatted: represent
# Formatted: represent
# Unformatted: make_up
# Formatted: make
# Unformatted: comprise
# Formatted: comprise
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: follow
# Formatted: follow
# Unformatted: embody
# Formatted: embody
# Unformatted: be
# Formatted: be
# Unformatted: personify
# Formatted: personify
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: live
# Formatted: live
# Unformatted: be
# Formatted: be
# Unformatted: cost
# Formatted: cost
# Unformatted: be
# Formatted: be
# Unformatted: brand
# Formatted: brand
# Unformatted: shuffle
# Formatted: shuffle
# Unformatted: shuffling
# Formatted: shuffling
# Unformatted: do
# Formatted: do
# Unformatted: get
# Formatted: get
# Unformatted: create
# Formatted: create
# Unformatted: induce
# Formatted: induce
# Unformatted: stimulate
# Formatted: stimulate
# Unformatted: cause
# Formatted: cause
# Unformatted: have
# Formatted: have
# Unformatted: get
# Formatted: get
# Unformatted: cause
# Formatted: cause
# Unformatted: do
# Formatted: do
# Unformatted: produce
# Formatted: produce
# Unformatted: create
# Formatted: create
# Unformatted: draw
# Formatted: draw
# Unformatted: create
# Formatted: create
# Unformatted: gain
# Formatted: gain
# Unformatted: take_in
# Formatted: take
# Unformatted: clear
# Formatted: clear
# Unformatted: earn
# Formatted: earn
# Unformatted: realize
# Formatted: realize
# Unformatted: realise
# Formatted: realise
# Unformatted: pull_in
# Formatted: pull
# Unformatted: bring_in
# Formatted: bring
# Unformatted: do
# Formatted: do
# Unformatted: form
# Formatted: form
# Unformatted: constitute
# Formatted: constitute
# Unformatted: reach
# Formatted: reach
# Unformatted: get_to
# Formatted: get
# Unformatted: progress_to
# Formatted: progress
# Unformatted: construct
# Formatted: construct
# Unformatted: build
# Formatted: build
# Unformatted: name
# Formatted: name
# Unformatted: nominate
# Formatted: nominate
# Unformatted: have
# Formatted: have
# Unformatted: get
# Formatted: get
# Unformatted: reach
# Formatted: reach
# Unformatted: attain
# Formatted: attain
# Unformatted: hit
# Formatted: hit
# Unformatted: arrive_at
# Formatted: arrive
# Unformatted: gain
# Formatted: gain
# Unformatted: lay_down
# Formatted: lay
# Unformatted: establish
# Formatted: establish
# Unformatted: hold
# Formatted: hold
# Unformatted: throw
# Formatted: throw
# Unformatted: have
# Formatted: have
# Unformatted: give
# Formatted: give
# Unformatted: make_up
# Formatted: make
# Unformatted: take
# Formatted: take
# Unformatted: stool
# Formatted: stool
# Unformatted: defecate
# Formatted: defecate
# Unformatted: shit
# Formatted: shit
# Unformatted: take_a_shit
# Formatted: take
# Unformatted: take_a_crap
# Formatted: take
# Unformatted: ca-ca
# Formatted: caca
# Unformatted: crap
# Formatted: crap
# Unformatted: work
# Formatted: work
# Unformatted: cook
# Formatted: cook
# Unformatted: fix
# Formatted: fix
# Unformatted: ready
# Formatted: ready
# Unformatted: prepare
# Formatted: prepare
# Unformatted: seduce
# Formatted: seduce
# Unformatted: score
# Formatted: score
# Unformatted: pretend
# Formatted: pretend
# Unformatted: make_believe
# Formatted: make
# Unformatted: urinate
# Formatted: urinate
# Unformatted: piddle
# Formatted: piddle
# Unformatted: puddle
# Formatted: puddle
# Unformatted: micturate
# Formatted: micturate
# Unformatted: piss
# Formatted: piss
# Unformatted: pee
# Formatted: pee
# Unformatted: pee-pee
# Formatted: peepee
# Unformatted: make_water
# Formatted: make
# Unformatted: relieve_oneself
# Formatted: relieve
# Unformatted: take_a_leak
# Formatted: take
# Unformatted: spend_a_penny
# Formatted: spend
# Unformatted: wee
# Formatted: wee
# Unformatted: wee-wee
# Formatted: weewee
# Unformatted: pass_water
# Formatted: pass
# Unformatted: populate
# Formatted: populate
# Unformatted: dwell
# Formatted: dwell
# Unformatted: inhabit
# Formatted: inhabit
# Unformatted: survive
# Formatted: survive
# Unformatted: last
# Formatted: last
# Unformatted: live_on
# Formatted: live
# Unformatted: go
# Formatted: go
# Unformatted: endure
# Formatted: endure
# Unformatted: hold_up
# Formatted: hold
# Unformatted: hold_out
# Formatted: hold
# Unformatted: exist
# Formatted: exist
# Unformatted: survive
# Formatted: survive
# Unformatted: subsist
# Formatted: subsist
# Unformatted: be
# Formatted: be
# Unformatted: know
# Formatted: know
# Unformatted: experience
# Formatted: experience
# Unformatted: unrecorded
# Formatted: unrecorded
# Unformatted: alive
# Formatted: alive
# Unformatted: bouncy
# Formatted: bouncy
# Unformatted: lively
# Formatted: lively
# Unformatted: resilient
# Formatted: resilient
# Unformatted: springy
# Formatted: springy
# Unformatted: hot
# Formatted: hot
# Unformatted: alive
# Formatted: alive
# Unformatted: wherefore
# Formatted: wherefore
# Unformatted: subsequently
# Formatted: subsequently
# Unformatted: later
# Formatted: later
# Unformatted: afterwards
# Formatted: afterwards
# Unformatted: afterward
# Formatted: afterward
# Unformatted: later_on
# Formatted: later
# Unformatted: 1
# Formatted: 1
# Unformatted: I
# Formatted: i
# Unformatted: ace
# Formatted: ace
# Unformatted: single
# Formatted: single
# Unformatted: unity
# Formatted: unity
# Unformatted: 1
# Formatted: 1
# Unformatted: i
# Formatted: i
# Unformatted: ane
# Formatted: ane
# Unformatted: unitary
# Formatted: unitary
# Unformatted: matchless
# Formatted: matchless
# Unformatted: nonpareil
# Formatted: nonpareil
# Unformatted: one_and_only
# Formatted: one
# Unformatted: peerless
# Formatted: peerless
# Unformatted: unmatched
# Formatted: unmatched
# Unformatted: unmatchable
# Formatted: unmatchable
# Unformatted: unrivaled
# Formatted: unrivaled
# Unformatted: unrivalled
# Formatted: unrivalled
# Unformatted: inch
# Formatted: inch
# Unformatted: indium
# Formatted: indium
# Unformatted: In
# Formatted: in
# Unformatted: atomic_number_49
# Formatted: atomic
# Unformatted: Indiana
# Formatted: indiana
# Unformatted: Hoosier_State
# Formatted: hoosier
# Unformatted: IN
# Formatted: in
# Unformatted: inwards
# Formatted: inwards
# Unformatted: inward
# Formatted: inward
# Unformatted: four
# Formatted: four
# Unformatted: IV
# Formatted: iv
# Unformatted: tetrad
# Formatted: tetrad
# Unformatted: quatern
# Formatted: quatern
# Unformatted: quaternion
# Formatted: quaternion
# Unformatted: quaternary
# Formatted: quaternary
# Unformatted: quaternity
# Formatted: quaternity
# Unformatted: quartet
# Formatted: quartet
# Unformatted: quadruplet
# Formatted: quadruplet
# Unformatted: foursome
# Formatted: foursome
# Unformatted: Little_Joe
# Formatted: little
# Unformatted: four
# Formatted: four
# Unformatted: iv
# Formatted: iv
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: exist
# Formatted: exist
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: equal
# Formatted: equal
# Unformatted: be
# Formatted: be
# Unformatted: constitute
# Formatted: constitute
# Unformatted: represent
# Formatted: represent
# Unformatted: make_up
# Formatted: make
# Unformatted: comprise
# Formatted: comprise
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: follow
# Formatted: follow
# Unformatted: embody
# Formatted: embody
# Unformatted: be
# Formatted: be
# Unformatted: personify
# Formatted: personify
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: live
# Formatted: live
# Unformatted: be
# Formatted: be
# Unformatted: cost
# Formatted: cost
# Unformatted: be
# Formatted: be
# Unformatted: free_people
# Formatted: free
# Unformatted: liberate
# Formatted: liberate
# Unformatted: release
# Formatted: release
# Unformatted: unloose
# Formatted: unloose
# Unformatted: unloosen
# Formatted: unloosen
# Unformatted: loose
# Formatted: loose
# Unformatted: rid
# Formatted: rid
# Unformatted: disembarrass
# Formatted: disembarrass
# Unformatted: dislodge
# Formatted: dislodge
# Unformatted: exempt
# Formatted: exempt
# Unformatted: relieve
# Formatted: relieve
# Unformatted: release
# Formatted: release
# Unformatted: discharge
# Formatted: discharge
# Unformatted: disengage
# Formatted: disengage
# Unformatted: absolve
# Formatted: absolve
# Unformatted: justify
# Formatted: justify
# Unformatted: release
# Formatted: release
# Unformatted: relinquish
# Formatted: relinquish
# Unformatted: resign
# Formatted: resign
# Unformatted: give_up
# Formatted: give
# Unformatted: release
# Formatted: release
# Unformatted: liberate
# Formatted: liberate
# Unformatted: unblock
# Formatted: unblock
# Unformatted: unfreeze
# Formatted: unfreeze
# Unformatted: release
# Formatted: release
# Unformatted: complimentary
# Formatted: complimentary
# Unformatted: costless
# Formatted: costless
# Unformatted: gratis
# Formatted: gratis
# Unformatted: gratuitous
# Formatted: gratuitous
# Unformatted: detached
# Formatted: detached
# Unformatted: spare
# Formatted: spare
# Unformatted: barren
# Formatted: barren
# Unformatted: destitute
# Formatted: destitute
# Unformatted: devoid
# Formatted: devoid
# Unformatted: innocent
# Formatted: innocent
# Unformatted: loose
# Formatted: loose
# Unformatted: liberal
# Formatted: liberal
# Unformatted: loose
# Formatted: loose
# Unformatted: appearance
# Formatted: appearance
# Unformatted: coming_into_court
# Formatted: coming
# Unformatted: look
# Formatted: look
# Unformatted: appear
# Formatted: appear
# Unformatted: seem
# Formatted: seem
# Unformatted: appear
# Formatted: appear
# Unformatted: appear
# Formatted: appear
# Unformatted: come_out
# Formatted: come
# Unformatted: appear
# Formatted: appear
# Unformatted: seem
# Formatted: seem
# Unformatted: appear
# Formatted: appear
# Unformatted: come_along
# Formatted: come
# Unformatted: appear
# Formatted: appear
# Unformatted: appear
# Formatted: appear
# Unformatted: along
# Formatted: along
# Unformatted: pendant
# Formatted: pendant
# Unformatted: pendent
# Formatted: pendent
# Unformatted: excavation
# Formatted: excavation
# Unformatted: archeological_site
# Formatted: archeological
# Unformatted: shot
# Formatted: shot
# Unformatted: shaft
# Formatted: shaft
# Unformatted: slam
# Formatted: slam
# Unformatted: barb
# Formatted: barb
# Unformatted: jibe
# Formatted: jibe
# Unformatted: gibe
# Formatted: gibe
# Unformatted: excavation
# Formatted: excavation
# Unformatted: digging
# Formatted: digging
# Unformatted: jab
# Formatted: jab
# Unformatted: delve
# Formatted: delve
# Unformatted: cut_into
# Formatted: cut
# Unformatted: turn_over
# Formatted: turn
# Unformatted: dig_out
# Formatted: dig
# Unformatted: labor
# Formatted: labor
# Unformatted: labour
# Formatted: labour
# Unformatted: toil
# Formatted: toil
# Unformatted: fag
# Formatted: fag
# Unformatted: travail
# Formatted: travail
# Unformatted: grind
# Formatted: grind
# Unformatted: drudge
# Formatted: drudge
# Unformatted: moil
# Formatted: moil
# Unformatted: dig_up
# Formatted: dig
# Unformatted: dig_out
# Formatted: dig
# Unformatted: excavate
# Formatted: excavate
# Unformatted: hollow
# Formatted: hollow
# Unformatted: jab
# Formatted: jab
# Unformatted: prod
# Formatted: prod
# Unformatted: stab
# Formatted: stab
# Unformatted: poke
# Formatted: poke
# Unformatted: grok
# Formatted: grok
# Unformatted: get_the_picture
# Formatted: get
# Unformatted: comprehend
# Formatted: comprehend
# Unformatted: savvy
# Formatted: savvy
# Unformatted: grasp
# Formatted: grasp
# Unformatted: compass
# Formatted: compass
# Unformatted: apprehend
# Formatted: apprehend
# Unformatted: More
# Formatted: more
# Unformatted: Thomas_More
# Formatted: thomas
# Unformatted: Sir_Thomas_More
# Formatted: sir
# Unformatted: more_than
# Formatted: more
# Unformatted: to_a_greater_extent
# Formatted: to
# Unformatted: iodine
# Formatted: iodine
# Unformatted: iodin
# Formatted: iodin
# Unformatted: atomic_number_53
# Formatted: atomic
# Unformatted: one
# Formatted: one
# Unformatted: 1
# Formatted: 1
# Unformatted: ace
# Formatted: ace
# Unformatted: single
# Formatted: single
# Unformatted: unity
# Formatted: unity
# Unformatted: i
# Formatted: i
# Unformatted: one
# Formatted: one
# Unformatted: 1
# Formatted: 1
# Unformatted: i
# Formatted: i
# Unformatted: ane
# Formatted: ane
# Unformatted: information_technology
# Formatted: information
# Unformatted: IT
# Formatted: it
# Unformatted: angstrom
# Formatted: angstrom
# Unformatted: angstrom_unit
# Formatted: angstrom
# Unformatted: A
# Formatted: a
# Unformatted: vitamin_A
# Formatted: vitamin
# Unformatted: antiophthalmic_factor
# Formatted: antiophthalmic
# Unformatted: axerophthol
# Formatted: axerophthol
# Unformatted: A
# Formatted: a
# Unformatted: deoxyadenosine_monophosphate
# Formatted: deoxyadenosine
# Unformatted: A
# Formatted: a
# Unformatted: adenine
# Formatted: adenine
# Unformatted: A
# Formatted: a
# Unformatted: ampere
# Formatted: ampere
# Unformatted: amp
# Formatted: amp
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: type_A
# Formatted: type
# Unformatted: group_A
# Formatted: group
# Unformatted: mustiness
# Formatted: mustiness
# Unformatted: moldiness
# Formatted: moldiness
# Unformatted: non
# Formatted: non
# Unformatted: beingness
# Formatted: beingness
# Unformatted: existence
# Formatted: existence
# Unformatted: organism
# Formatted: organism
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: exist
# Formatted: exist
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: equal
# Formatted: equal
# Unformatted: be
# Formatted: be
# Unformatted: constitute
# Formatted: constitute
# Unformatted: represent
# Formatted: represent
# Unformatted: make_up
# Formatted: make
# Unformatted: comprise
# Formatted: comprise
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: follow
# Formatted: follow
# Unformatted: embody
# Formatted: embody
# Unformatted: be
# Formatted: be
# Unformatted: personify
# Formatted: personify
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: live
# Formatted: live
# Unformatted: be
# Formatted: be
# Unformatted: cost
# Formatted: cost
# Unformatted: be
# Formatted: be
# Unformatted: merely
# Formatted: merely
# Unformatted: simply
# Formatted: simply
# Unformatted: just
# Formatted: just
# Unformatted: only
# Formatted: only
# Unformatted: wellspring
# Formatted: wellspring
# Unformatted: fountainhead
# Formatted: fountainhead
# Unformatted: swell
# Formatted: swell
# Unformatted: good
# Formatted: good
# Unformatted: good
# Formatted: good
# Unformatted: easily
# Formatted: easily
# Unformatted: considerably
# Formatted: considerably
# Unformatted: substantially
# Formatted: substantially
# Unformatted: intimately
# Formatted: intimately
# Unformatted: advantageously
# Formatted: advantageously
# Unformatted: comfortably
# Formatted: comfortably
# Unformatted: win
# Formatted: win
# Unformatted: acquire
# Formatted: acquire
# Unformatted: win
# Formatted: win
# Unformatted: gain
# Formatted: gain
# Unformatted: gain
# Formatted: gain
# Unformatted: advance
# Formatted: advance
# Unformatted: win
# Formatted: win
# Unformatted: pull_ahead
# Formatted: pull
# Unformatted: make_headway
# Formatted: make
# Unformatted: get_ahead
# Formatted: get
# Unformatted: gain_ground
# Formatted: gain
# Unformatted: succeed
# Formatted: succeed
# Unformatted: win
# Formatted: win
# Unformatted: come_through
# Formatted: come
# Unformatted: bring_home_the_bacon
# Formatted: bring
# Unformatted: deliver_the_goods
# Formatted: deliver
# Unformatted: victorious
# Formatted: victorious
# Unformatted: fetching
# Formatted: fetching
# Unformatted: taking
# Formatted: taking
# Unformatted: astatine
# Formatted: astatine
# Unformatted: At
# Formatted: at
# Unformatted: atomic_number_85
# Formatted: atomic
# Unformatted: human_face
# Formatted: human
# Unformatted: expression
# Formatted: expression
# Unformatted: look
# Formatted: look
# Unformatted: aspect
# Formatted: aspect
# Unformatted: facial_expression
# Formatted: facial
# Unformatted: side
# Formatted: side
# Unformatted: grimace
# Formatted: grimace
# Unformatted: font
# Formatted: font
# Unformatted: fount
# Formatted: fount
# Unformatted: typeface
# Formatted: typeface
# Unformatted: case
# Formatted: case
# Unformatted: boldness
# Formatted: boldness
# Unformatted: nerve
# Formatted: nerve
# Unformatted: brass
# Formatted: brass
# Unformatted: cheek
# Formatted: cheek
# Unformatted: confront
# Formatted: confront
# Unformatted: face_up
# Formatted: face
# Unformatted: confront
# Formatted: confront
# Unformatted: front
# Formatted: front
# Unformatted: look
# Formatted: look
# Unformatted: confront
# Formatted: confront
# Unformatted: present
# Formatted: present
# Unformatted: understand
# Formatted: understand
# Unformatted: realize
# Formatted: realize
# Unformatted: realise
# Formatted: realise
# Unformatted: witness
# Formatted: witness
# Unformatted: find
# Formatted: find
# Unformatted: visualize
# Formatted: visualize
# Unformatted: visualise
# Formatted: visualise
# Unformatted: envision
# Formatted: envision
# Unformatted: project
# Formatted: project
# Unformatted: fancy
# Formatted: fancy
# Unformatted: figure
# Formatted: figure
# Unformatted: picture
# Formatted: picture
# Unformatted: image
# Formatted: image
# Unformatted: consider
# Formatted: consider
# Unformatted: reckon
# Formatted: reckon
# Unformatted: view
# Formatted: view
# Unformatted: regard
# Formatted: regard
# Unformatted: learn
# Formatted: learn
# Unformatted: hear
# Formatted: hear
# Unformatted: get_word
# Formatted: get
# Unformatted: get_wind
# Formatted: get
# Unformatted: pick_up
# Formatted: pick
# Unformatted: find_out
# Formatted: find
# Unformatted: get_a_line
# Formatted: get
# Unformatted: discover
# Formatted: discover
# Unformatted: watch
# Formatted: watch
# Unformatted: view
# Formatted: view
# Unformatted: catch
# Formatted: catch
# Unformatted: take_in
# Formatted: take
# Unformatted: meet
# Formatted: meet
# Unformatted: run_into
# Formatted: run
# Unformatted: encounter
# Formatted: encounter
# Unformatted: run_across
# Formatted: run
# Unformatted: come_across
# Formatted: come
# Unformatted: determine
# Formatted: determine
# Unformatted: check
# Formatted: check
# Unformatted: find_out
# Formatted: find
# Unformatted: ascertain
# Formatted: ascertain
# Unformatted: watch
# Formatted: watch
# Unformatted: learn
# Formatted: learn
# Unformatted: check
# Formatted: check
# Unformatted: insure
# Formatted: insure
# Unformatted: see_to_it
# Formatted: see
# Unformatted: ensure
# Formatted: ensure
# Unformatted: control
# Formatted: control
# Unformatted: ascertain
# Formatted: ascertain
# Unformatted: assure
# Formatted: assure
# Unformatted: visit
# Formatted: visit
# Unformatted: attend
# Formatted: attend
# Unformatted: take_care
# Formatted: take
# Unformatted: look
# Formatted: look
# Unformatted: go_steady
# Formatted: go
# Unformatted: go_out
# Formatted: go
# Unformatted: date
# Formatted: date
# Unformatted: examine
# Formatted: examine
# Unformatted: experience
# Formatted: experience
# Unformatted: go_through
# Formatted: go
# Unformatted: escort
# Formatted: escort
# Unformatted: interpret
# Formatted: interpret
# Unformatted: construe
# Formatted: construe
# Unformatted: rich_person
# Formatted: rich
# Unformatted: wealthy_person
# Formatted: wealthy
# Unformatted: have_got
# Formatted: have
# Unformatted: hold
# Formatted: hold
# Unformatted: feature
# Formatted: feature
# Unformatted: experience
# Formatted: experience
# Unformatted: receive
# Formatted: receive
# Unformatted: get
# Formatted: get
# Unformatted: own
# Formatted: own
# Unformatted: possess
# Formatted: possess
# Unformatted: get
# Formatted: get
# Unformatted: let
# Formatted: let
# Unformatted: consume
# Formatted: consume
# Unformatted: ingest
# Formatted: ingest
# Unformatted: take_in
# Formatted: take
# Unformatted: take
# Formatted: take
# Unformatted: hold
# Formatted: hold
# Unformatted: throw
# Formatted: throw
# Unformatted: make
# Formatted: make
# Unformatted: give
# Formatted: give
# Unformatted: experience
# Formatted: experience
# Unformatted: induce
# Formatted: induce
# Unformatted: stimulate
# Formatted: stimulate
# Unformatted: cause
# Formatted: cause
# Unformatted: get
# Formatted: get
# Unformatted: make
# Formatted: make
# Unformatted: accept
# Formatted: accept
# Unformatted: take
# Formatted: take
# Unformatted: receive
# Formatted: receive
# Unformatted: suffer
# Formatted: suffer
# Unformatted: sustain
# Formatted: sustain
# Unformatted: get
# Formatted: get
# Unformatted: get
# Formatted: get
# Unformatted: make
# Formatted: make
# Unformatted: give_birth
# Formatted: give
# Unformatted: deliver
# Formatted: deliver
# Unformatted: bear
# Formatted: bear
# Unformatted: birth
# Formatted: birth
# Unformatted: take
# Formatted: take
# Unformatted: lone
# Formatted: lone
# Unformatted: lonesome
# Formatted: lonesome
# Unformatted: sole
# Formatted: sole
# Unformatted: solitary
# Formatted: solitary
# Unformatted: alone
# Formatted: alone
# Unformatted: merely
# Formatted: merely
# Unformatted: simply
# Formatted: simply
# Unformatted: just
# Formatted: just
# Unformatted: but
# Formatted: but
# Unformatted: entirely
# Formatted: entirely
# Unformatted: exclusively
# Formatted: exclusively
# Unformatted: solely
# Formatted: solely
# Unformatted: alone
# Formatted: alone
# Unformatted: only_if
# Formatted: only
# Unformatted: only_when
# Formatted: only
# Unformatted: iodine
# Formatted: iodine
# Unformatted: iodin
# Formatted: iodin
# Unformatted: atomic_number_53
# Formatted: atomic
# Unformatted: one
# Formatted: one
# Unformatted: 1
# Formatted: 1
# Unformatted: ace
# Formatted: ace
# Unformatted: single
# Formatted: single
# Unformatted: unity
# Formatted: unity
# Unformatted: i
# Formatted: i
# Unformatted: one
# Formatted: one
# Unformatted: 1
# Formatted: 1
# Unformatted: i
# Formatted: i
# Unformatted: ane
# Formatted: ane
# Unformatted: More
# Formatted: more
# Unformatted: Thomas_More
# Formatted: thomas
# Unformatted: Sir_Thomas_More
# Formatted: sir
# Unformatted: more_than
# Formatted: more
# Unformatted: to_a_greater_extent
# Formatted: to
# Unformatted: angstrom
# Formatted: angstrom
# Unformatted: angstrom_unit
# Formatted: angstrom
# Unformatted: A
# Formatted: a
# Unformatted: vitamin_A
# Formatted: vitamin
# Unformatted: antiophthalmic_factor
# Formatted: antiophthalmic
# Unformatted: axerophthol
# Formatted: axerophthol
# Unformatted: A
# Formatted: a
# Unformatted: deoxyadenosine_monophosphate
# Formatted: deoxyadenosine
# Unformatted: A
# Formatted: a
# Unformatted: adenine
# Formatted: adenine
# Unformatted: A
# Formatted: a
# Unformatted: ampere
# Formatted: ampere
# Unformatted: amp
# Formatted: amp
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: type_A
# Formatted: type
# Unformatted: group_A
# Formatted: group
# Unformatted: sound
# Formatted: sound
# Unformatted: sound
# Formatted: sound
# Unformatted: auditory_sensation
# Formatted: auditory
# Unformatted: sound
# Formatted: sound
# Unformatted: sound
# Formatted: sound
# Unformatted: audio
# Formatted: audio
# Unformatted: sound
# Formatted: sound
# Unformatted: phone
# Formatted: phone
# Unformatted: speech_sound
# Formatted: speech
# Unformatted: sound
# Formatted: sound
# Unformatted: strait
# Formatted: strait
# Unformatted: sound
# Formatted: sound
# Unformatted: sound
# Formatted: sound
# Unformatted: sound
# Formatted: sound
# Unformatted: sound
# Formatted: sound
# Unformatted: go
# Formatted: go
# Unformatted: sound
# Formatted: sound
# Unformatted: sound
# Formatted: sound
# Unformatted: voice
# Formatted: voice
# Unformatted: sound
# Formatted: sound
# Unformatted: vocalize
# Formatted: vocalize
# Unformatted: vocalise
# Formatted: vocalise
# Unformatted: sound
# Formatted: sound
# Unformatted: fathom
# Formatted: fathom
# Unformatted: sound
# Formatted: sound
# Unformatted: angstrom
# Formatted: angstrom
# Unformatted: angstrom_unit
# Formatted: angstrom
# Unformatted: A
# Formatted: a
# Unformatted: vitamin_A
# Formatted: vitamin
# Unformatted: antiophthalmic_factor
# Formatted: antiophthalmic
# Unformatted: axerophthol
# Formatted: axerophthol
# Unformatted: A
# Formatted: a
# Unformatted: deoxyadenosine_monophosphate
# Formatted: deoxyadenosine
# Unformatted: A
# Formatted: a
# Unformatted: adenine
# Formatted: adenine
# Unformatted: A
# Formatted: a
# Unformatted: ampere
# Formatted: ampere
# Unformatted: amp
# Formatted: amp
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: type_A
# Formatted: type
# Unformatted: group_A
# Formatted: group
# Unformatted: not
# Formatted: not
# Unformatted: non
# Formatted: non
# Unformatted: Washington
# Formatted: washington
# Unformatted: Evergreen_State
# Formatted: evergreen
# Unformatted: WA
# Formatted: wa
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: exist
# Formatted: exist
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: equal
# Formatted: equal
# Unformatted: be
# Formatted: be
# Unformatted: constitute
# Formatted: constitute
# Unformatted: represent
# Formatted: represent
# Unformatted: make_up
# Formatted: make
# Unformatted: comprise
# Formatted: comprise
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: follow
# Formatted: follow
# Unformatted: embody
# Formatted: embody
# Unformatted: be
# Formatted: be
# Unformatted: personify
# Formatted: personify
# Unformatted: be
# Formatted: be
# Unformatted: be
# Formatted: be
# Unformatted: live
# Formatted: live
# Unformatted: be
# Formatted: be
# Unformatted: cost
# Formatted: cost
# Unformatted: be
# Formatted: be
# Unformatted: along
# Formatted: along
# Unformatted: angstrom
# Formatted: angstrom
# Unformatted: angstrom_unit
# Formatted: angstrom
# Unformatted: A
# Formatted: a
# Unformatted: vitamin_A
# Formatted: vitamin
# Unformatted: antiophthalmic_factor
# Formatted: antiophthalmic
# Unformatted: axerophthol
# Formatted: axerophthol
# Unformatted: A
# Formatted: a
# Unformatted: deoxyadenosine_monophosphate
# Formatted: deoxyadenosine
# Unformatted: A
# Formatted: a
# Unformatted: adenine
# Formatted: adenine
# Unformatted: A
# Formatted: a
# Unformatted: ampere
# Formatted: ampere
# Unformatted: amp
# Formatted: amp
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: type_A
# Formatted: type
# Unformatted: group_A
# Formatted: group
#
#
# PREDICTIONS: ['I', 'the', 'do', '(PS', 'be', 'for', 'mixing', 'Sunday', 'to', 'was', 'your', 'for', '|', 'make', 'live', 'why', 'after', 'http…', 'hahhaa', 'the', 'one', 'car!!!', 'in', '4', 'is', 'free', 'and', ',', 'and', 'wonderland', 'label..prod.', 'too.', 'appearing', 'the', 'on', '', '', 'the', 'chandelier', '', 'dig', 'more', '', 'I', 'with', 'it', 'a', 'must', ':s', 'him', '$7.99', 'not', 'to', 'to', 'being', 'but', ':', 'hotel', 'the', 'well', '-5', '.', 'winning', 'at', '"Colferiacs."', 'face', 'see', '?????', 'With', 'have', ':)', 'only', ':', 'to', 'I', '!', 'more', 'a', ')', 'sounds', '@nogikakiko:', 'a', 'Not', 'heartbroken,but', 'she', 'St.', 'was', 'on', 'did)', '.', 'a', 'and']
# ACTUAL: ['i', '@slackerradio', 'rock', 'i', 'bee', 'for', 'though', 'bowl', 'to', 'was', 'nothing', 'would', 'http://twitpiccom/10tti2', 'leave', 'love', 'why', 'before', 'may', 'ha', 'my', 'feature', 'old', 'in', 'please', 'is', 'songs', 'delivered', 'in', 'with', 'curious', 'bloggerslets', 'to', 'multiple', 'the', 'yung', 'personal', 'for', 'a', 'may', 'modern', 'read', '#friendsthemovie', 'and', 'prep', 'with', 'home', 'tweet', 'remain', 'sleephmmm', 'for', '2/10', 'confusedare', 'bottle', 'to', 'to', 'but', 'http://owly/14ljw', 'house', 'london', 'a', 'will', ';d', 'winning', 'at', 'as', 'face', 'see', 'zhanghuangbin', 'with', 'you', 'a', 'going', '20', 'to', 'i', 'or', 'still', 'black', 'live', 'cant', '@shimay', 'right', 'not', 'smootha', 'carmen', 'st', 'mondayfriday', 'for', 'had', 'this', 'more', 'to']
#
# Predicted: I
# Prediction Synonyms:
# ['i', 'iodine', 'iodin', 'atomic', 'one', '1', 'ace', 'single', 'unity', 'i', 'one', '1', 'i', 'ane']
# Actual: i
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: the
# Prediction Synonyms:
# ['the']
# Actual: @slackerradio
#
# Predicted: do
# Prediction Synonyms:
# ['do', 'bash', 'brawl', 'doh', 'ut', 'doctor', 'do', 'make', 'perform', 'execute', 'perform', 'fare', 'make', 'come', 'get', 'cause', 'make', 'practice', 'practise', 'exercise', 'suffice', 'answer', 'serve', 'make', 'act', 'behave', 'serve', 'manage', 'dress', 'arrange', 'set', 'coif', 'coiffe', 'coiffure']
# Actual: rock
#
# Predicted: (PS
# Prediction Synonyms:
# ['(ps']
# Actual: i
#
# Predicted: be
# Prediction Synonyms:
# ['be', 'beryllium', 'be', 'glucinium', 'atomic', 'exist', 'equal', 'constitute', 'represent', 'make', 'comprise', 'follow', 'embody', 'personify', 'live', 'cost']
# Actual: bee
#
# Predicted: for
# Prediction Synonyms:
# ['for']
# Actual: for
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: mixing
# Prediction Synonyms:
# ['mixing', 'mix', 'commixture', 'admixture', 'mixture', 'intermixture', 'blend', 'flux', 'mix', 'conflate', 'commingle', 'immix', 'fuse', 'coalesce', 'meld', 'combine', 'merge', 'desegregate', 'integrate', 'mix', 'mix', 'mix', 'mix', 'mix', 'mingle', 'commix', 'unify', 'amalgamate', 'shuffle', 'ruffle', 'mix']
# Actual: though
#
# Predicted: Sunday
# Prediction Synonyms:
# ['sunday', "lord's", 'dominicus', 'sun', 'billy', 'william']
# Actual: bowl
#
# Predicted: to
# Prediction Synonyms:
# ['to']
# Actual: to
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: was
# Prediction Synonyms:
# ['was', 'washington', 'evergreen', 'wa', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual: was
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: your
# Prediction Synonyms:
# ['your']
# Actual: nothing
#
# Predicted: for
# Prediction Synonyms:
# ['for']
# Actual: would
#
# Predicted: |
# Prediction Synonyms:
# ['|']
# Actual: http://twitpiccom/10tti2
#
# Predicted: make
# Prediction Synonyms:
# ['make', 'brand', 'shuffle', 'shuffling', 'do', 'get', 'create', 'induce', 'stimulate', 'cause', 'have', 'get', 'cause', 'do', 'produce', 'create', 'draw', 'create', 'gain', 'take', 'clear', 'earn', 'realize', 'realise', 'pull', 'bring', 'do', 'form', 'constitute', 'reach', 'get', 'progress', 'construct', 'build', 'name', 'nominate', 'have', 'get', 'reach', 'attain', 'hit', 'arrive', 'gain', 'lay', 'establish', 'hold', 'throw', 'have', 'give', 'make', 'take', 'stool', 'defecate', 'shit', 'take', 'take', 'caca', 'crap', 'work', 'cook', 'fix', 'ready', 'prepare', 'seduce', 'score', 'pretend', 'make', 'urinate', 'piddle', 'puddle', 'micturate', 'piss', 'pee', 'peepee', 'make', 'relieve', 'take', 'spend', 'wee', 'weewee', 'pass']
# Actual: leave
#
# Predicted: live
# Prediction Synonyms:
# ['live', 'populate', 'dwell', 'inhabit', 'survive', 'last', 'live', 'go', 'endure', 'hold', 'hold', 'exist', 'survive', 'subsist', 'be', 'know', 'experience', 'unrecorded', 'alive', 'bouncy', 'lively', 'resilient', 'springy', 'hot', 'alive']
# Actual: love
#
# Predicted: why
# Prediction Synonyms:
# ['why', 'wherefore']
# Actual: why
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: after
# Prediction Synonyms:
# ['after', 'subsequently', 'later', 'afterwards', 'afterward', 'later']
# Actual: before
#
# Predicted: http…
# Prediction Synonyms:
# ['http…']
# Actual: may
#
# Predicted: hahhaa
# Prediction Synonyms:
# ['hahhaa']
# Actual: ha
#
# Predicted: the
# Prediction Synonyms:
# ['the']
# Actual: my
#
# Predicted: one
# Prediction Synonyms:
# ['one', '1', 'i', 'ace', 'single', 'unity', '1', 'i', 'ane', 'unitary', 'matchless', 'nonpareil', 'one', 'peerless', 'unmatched', 'unmatchable', 'unrivaled', 'unrivalled']
# Actual: feature
#
# Predicted: car!!!
# Prediction Synonyms:
# ['car']
# Actual: old
#
# Predicted: in
# Prediction Synonyms:
# ['in', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward']
# Actual: in
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: 4
# Prediction Synonyms:
# ['4', 'four', 'iv', 'tetrad', 'quatern', 'quaternion', 'quaternary', 'quaternity', 'quartet', 'quadruplet', 'foursome', 'little', 'four', 'iv']
# Actual: please
#
# Predicted: is
# Prediction Synonyms:
# ['is', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual: is
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: free
# Prediction Synonyms:
# ['free', 'free', 'liberate', 'release', 'unloose', 'unloosen', 'loose', 'rid', 'disembarrass', 'dislodge', 'exempt', 'relieve', 'release', 'discharge', 'disengage', 'absolve', 'justify', 'release', 'relinquish', 'resign', 'give', 'release', 'liberate', 'unblock', 'unfreeze', 'release', 'complimentary', 'costless', 'gratis', 'gratuitous', 'detached', 'spare', 'barren', 'destitute', 'devoid', 'innocent', 'loose', 'liberal', 'loose']
# Actual: songs
#
# Predicted: and
# Prediction Synonyms:
# ['and']
# Actual: delivered
#
# Predicted: ,
# Prediction Synonyms:
# ['']
# Actual: in
#
# Predicted: and
# Prediction Synonyms:
# ['and']
# Actual: with
#
# Predicted: wonderland
# Prediction Synonyms:
# ['wonderland']
# Actual: curious
#
# Predicted: label..prod.
# Prediction Synonyms:
# ['labelprod']
# Actual: bloggerslets
#
# Predicted: too.
# Prediction Synonyms:
# ['too']
# Actual: to
#
# Predicted: appearing
# Prediction Synonyms:
# ['appearing', 'appearance', 'coming', 'look', 'appear', 'seem', 'appear', 'appear', 'come', 'appear', 'seem', 'appear', 'come', 'appear', 'appear']
# Actual: multiple
#
# Predicted: the
# Prediction Synonyms:
# ['the']
# Actual: the
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: on
# Prediction Synonyms:
# ['on', 'along']
# Actual: yung
#
# Predicted:
# Prediction Synonyms:
# ['']
# Actual: personal
#
# Predicted:
# Prediction Synonyms:
# ['']
# Actual: for
#
# Predicted: the
# Prediction Synonyms:
# ['the']
# Actual: a
#
# Predicted: chandelier
# Prediction Synonyms:
# ['chandelier', 'pendant', 'pendent']
# Actual: may
#
# Predicted:
# Prediction Synonyms:
# ['']
# Actual: modern
#
# Predicted: dig
# Prediction Synonyms:
# ['dig', 'excavation', 'archeological', 'shot', 'shaft', 'slam', 'barb', 'jibe', 'gibe', 'excavation', 'digging', 'jab', 'delve', 'cut', 'turn', 'dig', 'labor', 'labour', 'toil', 'fag', 'travail', 'grind', 'drudge', 'moil', 'dig', 'dig', 'excavate', 'hollow', 'jab', 'prod', 'stab', 'poke', 'grok', 'get', 'comprehend', 'savvy', 'grasp', 'compass', 'apprehend']
# Actual: read
#
# Predicted: more
# Prediction Synonyms:
# ['more', 'more', 'thomas', 'sir', 'more', 'to']
# Actual: #friendsthemovie
#
# Predicted:
# Prediction Synonyms:
# ['']
# Actual: and
#
# Predicted: I
# Prediction Synonyms:
# ['i', 'iodine', 'iodin', 'atomic', 'one', '1', 'ace', 'single', 'unity', 'i', 'one', '1', 'i', 'ane']
# Actual: prep
#
# Predicted: with
# Prediction Synonyms:
# ['with']
# Actual: with
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: it
# Prediction Synonyms:
# ['it', 'information', 'it']
# Actual: home
#
# Predicted: a
# Prediction Synonyms:
# ['a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group']
# Actual: tweet
#
# Predicted: must
# Prediction Synonyms:
# ['must', 'mustiness', 'moldiness']
# Actual: remain
#
# Predicted: :s
# Prediction Synonyms:
# [':s']
# Actual: sleephmmm
#
# Predicted: him
# Prediction Synonyms:
# ['him']
# Actual: for
#
# Predicted: $7.99
# Prediction Synonyms:
# ['$799']
# Actual: 2/10
#
# Predicted: not
# Prediction Synonyms:
# ['not', 'non']
# Actual: confusedare
#
# Predicted: to
# Prediction Synonyms:
# ['to']
# Actual: bottle
#
# Predicted: to
# Prediction Synonyms:
# ['to']
# Actual: to
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: being
# Prediction Synonyms:
# ['being', 'beingness', 'existence', 'organism', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual: to
#
# Predicted: but
# Prediction Synonyms:
# ['but', 'merely', 'simply', 'just', 'only']
# Actual: but
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: :
# Prediction Synonyms:
# [':']
# Actual: http://owly/14ljw
#
# Predicted: hotel
# Prediction Synonyms:
# ['hotel']
# Actual: house
#
# Predicted: the
# Prediction Synonyms:
# ['the']
# Actual: london
#
# Predicted: well
# Prediction Synonyms:
# ['well', 'wellspring', 'fountainhead', 'swell', 'good', 'good', 'easily', 'considerably', 'substantially', 'intimately', 'advantageously', 'comfortably']
# Actual: a
#
# Predicted: -5
# Prediction Synonyms:
# ['5']
# Actual: will
#
# Predicted: .
# Prediction Synonyms:
# ['']
# Actual: ;d
#
# Predicted: winning
# Prediction Synonyms:
# ['winning', 'win', 'acquire', 'win', 'gain', 'gain', 'advance', 'win', 'pull', 'make', 'get', 'gain', 'succeed', 'win', 'come', 'bring', 'deliver', 'victorious', 'fetching', 'taking']
# Actual: winning
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: at
# Prediction Synonyms:
# ['at', 'astatine', 'at', 'atomic']
# Actual: at
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: "Colferiacs."
# Prediction Synonyms:
# ['"colferiacs"']
# Actual: as
#
# Predicted: face
# Prediction Synonyms:
# ['face', 'human', 'expression', 'look', 'aspect', 'facial', 'side', 'grimace', 'font', 'fount', 'typeface', 'case', 'boldness', 'nerve', 'brass', 'cheek', 'confront', 'face', 'confront', 'front', 'look', 'confront', 'present']
# Actual: face
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: see
# Prediction Synonyms:
# ['see', 'understand', 'realize', 'realise', 'witness', 'find', 'visualize', 'visualise', 'envision', 'project', 'fancy', 'figure', 'picture', 'image', 'consider', 'reckon', 'view', 'regard', 'learn', 'hear', 'get', 'get', 'pick', 'find', 'get', 'discover', 'watch', 'view', 'catch', 'take', 'meet', 'run', 'encounter', 'run', 'come', 'determine', 'check', 'find', 'ascertain', 'watch', 'learn', 'check', 'insure', 'see', 'ensure', 'control', 'ascertain', 'assure', 'visit', 'attend', 'take', 'look', 'go', 'go', 'date', 'examine', 'experience', 'go', 'escort', 'interpret', 'construe']
# Actual: see
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: ?????
# Prediction Synonyms:
# ['']
# Actual: zhanghuangbin
#
# Predicted: With
# Prediction Synonyms:
# ['with']
# Actual: with
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: have
# Prediction Synonyms:
# ['have', 'rich', 'wealthy', 'have', 'hold', 'feature', 'experience', 'receive', 'get', 'own', 'possess', 'get', 'let', 'consume', 'ingest', 'take', 'take', 'hold', 'throw', 'make', 'give', 'experience', 'induce', 'stimulate', 'cause', 'get', 'make', 'accept', 'take', 'receive', 'suffer', 'sustain', 'get', 'get', 'make', 'give', 'deliver', 'bear', 'birth', 'take']
# Actual: you
#
# Predicted: :)
# Prediction Synonyms:
# [':)']
# Actual: a
#
# Predicted: only
# Prediction Synonyms:
# ['only', 'lone', 'lonesome', 'sole', 'solitary', 'alone', 'merely', 'simply', 'just', 'but', 'entirely', 'exclusively', 'solely', 'alone', 'only', 'only']
# Actual: going
#
# Predicted: :
# Prediction Synonyms:
# [':']
# Actual: 20
#
# Predicted: to
# Prediction Synonyms:
# ['to']
# Actual: to
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: I
# Prediction Synonyms:
# ['i', 'iodine', 'iodin', 'atomic', 'one', '1', 'ace', 'single', 'unity', 'i', 'one', '1', 'i', 'ane']
# Actual: i
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: !
# Prediction Synonyms:
# ['']
# Actual: or
#
# Predicted: more
# Prediction Synonyms:
# ['more', 'more', 'thomas', 'sir', 'more', 'to']
# Actual: still
#
# Predicted: a
# Prediction Synonyms:
# ['a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group']
# Actual: black
#
# Predicted: )
# Prediction Synonyms:
# [')']
# Actual: live
#
# Predicted: sounds
# Prediction Synonyms:
# ['sounds', 'sound', 'sound', 'auditory', 'sound', 'sound', 'audio', 'sound', 'phone', 'speech', 'sound', 'strait', 'sound', 'sound', 'sound', 'sound', 'go', 'sound', 'sound', 'voice', 'sound', 'vocalize', 'vocalise', 'sound', 'fathom', 'sound']
# Actual: cant
#
# Predicted: @nogikakiko:
# Prediction Synonyms:
# ['@nogikakiko:']
# Actual: @shimay
#
# Predicted: a
# Prediction Synonyms:
# ['a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group']
# Actual: right
#
# Predicted: Not
# Prediction Synonyms:
# ['not', 'not', 'non']
# Actual: not
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: heartbroken,but
# Prediction Synonyms:
# ['heartbrokenbut']
# Actual: smootha
#
# Predicted: she
# Prediction Synonyms:
# ['she']
# Actual: carmen
#
# Predicted: St.
# Prediction Synonyms:
# ['st']
# Actual: st
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: was
# Prediction Synonyms:
# ['was', 'washington', 'evergreen', 'wa', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual: mondayfriday
#
# Predicted: on
# Prediction Synonyms:
# ['on', 'along']
# Actual: for
#
# Predicted: did)
# Prediction Synonyms:
# ['did)']
# Actual: had
#
# Predicted: .
# Prediction Synonyms:
# ['']
# Actual: this
#
# Predicted: a
# Prediction Synonyms:
# ['a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group']
# Actual: more
#
# Predicted: and
# Prediction Synonyms:
# ['and']
# Actual: to
# Unformatted: DE
# Formatted: de
# Unformatted: Delaware
# Formatted: delaware
# Unformatted: Estado_Diamante
# Formatted: estado
# Unformatted: Primer_Estado
# Formatted: primer
# Unformatted: Y
# Formatted: y
# Unformatted: Y
# Formatted: y
# Unformatted: aviso
# Formatted: aviso
# Unformatted: consejo
# Formatted: consejo
# Unformatted: filtración
# Formatted: filtración
# Unformatted: idea
# Formatted: idea
# Unformatted: indicación
# Formatted: indicación
# Unformatted: información_confidencial
# Formatted: información
# Unformatted: ventaja
# Formatted: ventaja
# Unformatted: denuncia
# Formatted: denuncia
# Unformatted: DE
# Formatted: de
# Unformatted: Delaware
# Formatted: delaware
# Unformatted: Estado_Diamante
# Formatted: estado
# Unformatted: Primer_Estado
# Formatted: primer
# Unformatted: A
# Formatted: a
# Unformatted: DE
# Formatted: de
# Unformatted: Delaware
# Formatted: delaware
# Unformatted: Estado_Diamante
# Formatted: estado
# Unformatted: Primer_Estado
# Formatted: primer
# Unformatted: DE
# Formatted: de
# Unformatted: Delaware
# Formatted: delaware
# Unformatted: Estado_Diamante
# Formatted: estado
# Unformatted: Primer_Estado
# Formatted: primer
# Unformatted: ley_natural
# Formatted: ley
# Unformatted: acta
# Formatted: acta
# Unformatted: estatuto
# Formatted: estatuto
# Unformatted: jurisprudencia
# Formatted: jurisprudencia
# Unformatted: apariencia
# Formatted: apariencia
# Unformatted: aspecto
# Formatted: aspecto
# Unformatted: estampa
# Formatted: estampa
# Unformatted: forma
# Formatted: forma
# Unformatted: representación
# Formatted: representación
# Unformatted: fórmula
# Formatted: fórmula
# Unformatted: manifestación
# Formatted: manifestación
# Unformatted: reflejo
# Formatted: reflejo
# Unformatted: forma_de_hablar
# Formatted: forma
# Unformatted: giro
# Formatted: giro
# Unformatted: juego_de_palabras
# Formatted: juego
# Unformatted: emisión
# Formatted: emisión
# Unformatted: enunciado
# Formatted: enunciado
# Unformatted: locución
# Formatted: locución
# Unformatted: personas
# Formatted: personas
# Unformatted: pueblo
# Formatted: pueblo
# Unformatted: masa
# Formatted: masa
# Unformatted: multitud
# Formatted: multitud
# Unformatted: pueblo
# Formatted: pueblo
# Unformatted: tuerca
# Formatted: tuerca
# Unformatted: lo_mejor
# Formatted: lo
# Unformatted: no
# Formatted: no
# Unformatted: Y
# Formatted: y
# Unformatted: DE
# Formatted: de
# Unformatted: Delaware
# Formatted: delaware
# Unformatted: Estado_Diamante
# Formatted: estado
# Unformatted: Primer_Estado
# Formatted: primer
# Unformatted: negro
# Formatted: negro
# Unformatted: negro
# Formatted: negro
# Unformatted: negro
# Formatted: negro
# Unformatted: desalentador
# Formatted: desalentador
# Unformatted: negro
# Formatted: negro
# Unformatted: oscuro
# Formatted: oscuro
# Unformatted: triste
# Formatted: triste
# Unformatted: negro
# Formatted: negro
# Unformatted: negro
# Formatted: negro
# Unformatted: negro
# Formatted: negro
# Unformatted: oscuro
# Formatted: oscuro
# Unformatted: perverso
# Formatted: perverso
# Unformatted: siniestro
# Formatted: siniestro
# Unformatted: negro
# Formatted: negro
# Unformatted: sombrío
# Formatted: sombrío
# Unformatted: negro
# Formatted: negro
# Unformatted: negro
# Formatted: negro
# Unformatted: negro
# Formatted: negro
# Unformatted: negro
# Formatted: negro
# Unformatted: negro
# Formatted: negro
# Unformatted: A
# Formatted: a
# Unformatted: DE
# Formatted: de
# Unformatted: Delaware
# Formatted: delaware
# Unformatted: Estado_Diamante
# Formatted: estado
# Unformatted: Primer_Estado
# Formatted: primer
# Unformatted: acabar
# Formatted: acabar
# Unformatted: agotar
# Formatted: agotar
# Unformatted: utilizar
# Formatted: utilizar
# Unformatted: emplear
# Formatted: emplear
# Unformatted: utilizar
# Formatted: utilizar
# Unformatted: utilizar
# Formatted: utilizar
# Unformatted: aplicar
# Formatted: aplicar
# Unformatted: practicar
# Formatted: practicar
# Unformatted: absoluto
# Formatted: absoluto
# Unformatted: completo
# Formatted: completo
# Unformatted: puro
# Formatted: puro
# Unformatted: total
# Formatted: total
# Unformatted: absoluto
# Formatted: absoluto
# Unformatted: completo
# Formatted: completo
# Unformatted: total
# Formatted: total
# Unformatted: exacto
# Formatted: exacto
# Unformatted: preciso
# Formatted: preciso
# Unformatted: cero
# Formatted: cero
# Unformatted: DE
# Formatted: de
# Unformatted: Delaware
# Formatted: delaware
# Unformatted: Estado_Diamante
# Formatted: estado
# Unformatted: Primer_Estado
# Formatted: primer
# Unformatted: A
# Formatted: a
# Unformatted: Y
# Formatted: y
# Unformatted: cabeza
# Formatted: cabeza
# Unformatted: primer_plano
# Formatted: primer
# Unformatted: primera_fila
# Formatted: primera
# Unformatted: vanguardia
# Formatted: vanguardia
# Unformatted: presencia
# Formatted: presencia
# Unformatted: Q
# Formatted: q
#
#
# ...
# Unformatted: puddle
# Formatted: puddle
# Unformatted: kitty
# Formatted: kitty
# Unformatted: puddle
# Formatted: puddle
# Unformatted: pocket_billiards
# Formatted: pocket
# Unformatted: natatorio
# Formatted: natatorio
# Unformatted: pileta
# Formatted: pileta
# Unformatted: piscina
# Formatted: piscina
# Unformatted: angstrom
# Formatted: angstrom
# Unformatted: angstrom_unit
# Formatted: angstrom
# Unformatted: A
# Formatted: a
# Unformatted: vitamin_A
# Formatted: vitamin
# Unformatted: antiophthalmic_factor
# Formatted: antiophthalmic
# Unformatted: axerophthol
# Formatted: axerophthol
# Unformatted: A
# Formatted: a
# Unformatted: deoxyadenosine_monophosphate
# Formatted: deoxyadenosine
# Unformatted: A
# Formatted: a
# Unformatted: adenine
# Formatted: adenine
# Unformatted: A
# Formatted: a
# Unformatted: ampere
# Formatted: ampere
# Unformatted: amp
# Formatted: amp
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: A
# Formatted: a
# Unformatted: type_A
# Formatted: type
# Unformatted: group_A
# Formatted: group
# Unformatted: A
# Formatted: a
# Unformatted: digression
# Formatted: digression
# Unformatted: excursus
# Formatted: excursus
# Unformatted: divagation
# Formatted: divagation
# Unformatted: parenthesis
# Formatted: parenthesis
# Unformatted: away
# Formatted: away
# Unformatted: apart
# Formatted: apart
# Unformatted: away
# Formatted: away
# Unformatted: apart
# Formatted: apart
# Unformatted: by
# Formatted: by
# Unformatted: away
# Formatted: away
#
#
# PREDICTIONS: [')', 'y', 'ie:', 'an', 'we', 'what', 'afectan', '!', 'ien', 'is', '', 'really', 'his', '', 'was', 'great', 'lela,pero', 'trying', 'frente', 'y', 'pronunciación', 'my', 'bells', 'ach', 'together!', '.', 'Nobody', '😂😭', '.', 'in', 'del', '', 'perfect', '?', 'on', 'se', '', 'Possible', 'it', 'place', 'heard', '...', 'the', 'caja', 'que', 'of', 'lol', 'que', 'Year?', 'the', 'this', 'con', 'Columbia,', 'do', 'bellys,', 'Te', 'be', 'haha', 'over…', 'the', 'si', 'd', 'asleep', 'cortito', 'kasi', 'que', ',', 'day', '#Cyber', 'in', 'little', 'nana', 'dorar', 'jos', 'no', 'to', 'in', 'using', '', 'of', 'in', 'pool', 'a', '.', 'lng!', '', 'aside']
# ACTUAL: ['y', 'lea', 'cuñadas', 'the', 'we', "it's", 'te', 'fuck', 'ay', 'is', 'i’m', 'como', 'her', 'del', 'andaba', 'good', 'bien', 'trying', 'vacaciones', 'lol', 'la', 'me', 'bells', 'and', 'but', "that's", 'it', 'stay', 'ver', 'during', '', 'thatd', 'the', 'to', 'on', 'vuelvo', 'lmao', 't', 'a', 'so', 'saw', 'te', 'in', 'pic', 'me', 'of', 'ala', 'que', 'weekend', 'doing', 'it', 'para', 'and', 'hate', 'de', 'agarre', 'be', 'se', 'on', 'the', 'bien', 'los', 'asleep', 'notadoo', '3', 'sick', 'ni', 'day', 'friend', 'in', 'serious', 'padrino', 'a', 'signal', 'we', 'to', 'in', 'on', '>', 'from', 'in', 'super', 'everything', 'useless', 'el', 'podido', 'aside']
#
# Predicted: )
# Prediction Synonyms:
# [')', ')']
# Actual: y
#
# Predicted: y
# Prediction Synonyms:
# ['and', 'y', 'y']
# Actual: lea
#
# Predicted: ie:
# Prediction Synonyms:
# ['it is:', 'es que:']
# Actual: cuñadas
#
# Predicted: an
# Prediction Synonyms:
# ['an', 'una', 'associate', 'an']
# Actual: the
#
# Predicted: we
# Prediction Synonyms:
# ['we', 'nosotros']
# Actual: we
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: what
# Prediction Synonyms:
# ['what', '¿qué']
# Actual: it's
#
# Predicted: afectan
# Prediction Synonyms:
# ['affected', 'afectan', 'affect', 'impact', 'bear', 'bear', 'touch', 'touch', 'affect', 'involve', 'affect', 'regard', 'feign', 'sham', 'pretend', 'affect', 'dissemble', 'affect', 'impress', 'move', 'strike', 'unnatural', 'moved', 'stirred', 'touched']
# Actual: te
#
# Predicted: !
# Prediction Synonyms:
# ['', '¡¡¡ ¡']
# Actual: fuck
#
# Predicted: ien
# Prediction Synonyms:
# ['the nine', 'el neno']
# Actual: ay
#
# Predicted: is
# Prediction Synonyms:
# ['is', 'es', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual: is
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted:
# Prediction Synonyms:
# ['', '']
# Actual: i’m
#
# Predicted: really
# Prediction Synonyms:
# ['really', 'realmente', 'truly', 'genuinely', 'actually', 'in', 'truly', 'very', 'real', 'rattling']
# Actual: como
#
# Predicted: his
# Prediction Synonyms:
# ['his', 'su']
# Actual: her
#
# Predicted:
# Prediction Synonyms:
# ['', '']
# Actual: del
#
# Predicted: was
# Prediction Synonyms:
# ['was', 'fue', 'washington', 'evergreen', 'wa', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual: andaba
#
# Predicted: great
# Prediction Synonyms:
# ['great', 'gran', 'outstanding', 'bangup', 'bully', 'corking', 'cracking', 'dandy', 'groovy', 'keen', 'neat', 'nifty', 'not', 'peachy', 'slapup', 'swell', 'smashing', 'capital', 'majuscule', 'big', 'enceinte', 'expectant', 'gravid', 'large', 'heavy', 'with', 'gran', 'grande', 'importante', 'gran', 'grande', 'eminente', 'gran', 'gran', 'grande', 'gran', 'grande', 'fuerte', 'gran', 'grande', 'terrible', 'gran', 'gran', 'grande', 'gran', 'grande', 'importante', 'excelente', 'gran', 'grande', 'magnífico']
# Actual: good
#
# Predicted: lela,pero
# Prediction Synonyms:
# ['lela peru', 'puerta pero']
# Actual: bien
#
# Predicted: trying
# Prediction Synonyms:
# ['trying', 'intentando', 'try', 'seek', 'attempt', 'essay', 'assay', 'test', 'prove', 'try', 'try', 'examine', 'essay', 'judge', 'adjudicate', 'try', 'sample', 'try', 'try', 'taste', 'hear', 'try', 'try', 'try', 'strain', 'stress', 'try', 'render', 'try', 'try', 'nerveracking', 'nervewracking', 'stressful']
# Actual: trying
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: frente
# Prediction Synonyms:
# ['the front', 'frente', 'cabeza', 'primer', 'primera', 'vanguardia', 'presencia']
# Actual: vacaciones
#
# Predicted: y
# Prediction Synonyms:
# ['and', 'y', 'y']
# Actual: lol
#
# Predicted: pronunciación
# Prediction Synonyms:
# ['pronunciation', 'pronunciación', 'orthoepy']
# Actual: la
#
# Predicted: my
# Prediction Synonyms:
# ['my', 'mi']
# Actual: me
#
# Predicted: bells
# Prediction Synonyms:
# ['bells', 'bélgica', 'bell', 'doorbell', 'bell', 'buzzer', 'bell', 'toll', 'bell', "ship's", 'bell', 'bell', 'campana', 'bell', 'melville', 'alexander', 'bell', 'vanessa', 'vanessa', 'bell', 'alexander', 'alexander', 'chime', 'bell', 'gong', 'bell', 'bell']
# Actual: bells
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: ach
# Prediction Synonyms:
# ['ach', 'aqu']
# Actual: and
#
# Predicted: together!
# Prediction Synonyms:
# ['together', '¡juntos ¡']
# Actual: but
#
# Predicted: .
# Prediction Synonyms:
# ['', '']
# Actual: that's
#
# Predicted: Nobody
# Prediction Synonyms:
# ['nobody', 'nadie', 'cipher', 'cypher', 'nobody', 'nonentity']
# Actual: it
#
# Predicted: 😂😭
# Prediction Synonyms:
# ['😂😭', '😂😂']
# Actual: stay
#
# Predicted: .
# Prediction Synonyms:
# ['', '']
# Actual: ver
#
# Predicted: in
# Prediction Synonyms:
# ['in', 'en', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward', 'en', 'tuerca']
# Actual: during
#
# Predicted: del
# Prediction Synonyms:
# ['of', 'del']
# Actual:
#
# Predicted:
# Prediction Synonyms:
# ['', '']
# Actual: thatd
#
# Predicted: perfect
# Prediction Synonyms:
# ['perfect', 'perfecto', 'perfective', 'perfective', 'perfect', 'hone', 'arrant', 'complete', 'consummate', 'doubledyed', 'everlasting', 'gross', 'pure', 'sodding', 'stark', 'staring', 'thoroughgoing', 'utter', 'unadulterated', 'absoluto', 'completo', 'perfecto', 'puro', 'total', 'absoluto', 'completo', 'perfecto', 'total', 'exacto', 'perfecto', 'preciso', 'perfecto', 'perfecto']
# Actual: the
#
# Predicted: ?
# Prediction Synonyms:
# ['', '¿el']
# Actual: to
#
# Predicted: on
# Prediction Synonyms:
# ['on', 'en', 'along', 'en', 'tuerca']
# Actual: on
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: se
# Prediction Synonyms:
# ['by', 'si se', 'past', 'aside', 'away']
# Actual: vuelvo
#
# Predicted:
# Prediction Synonyms:
# ['', '']
# Actual: lmao
#
# Predicted: Possible
# Prediction Synonyms:
# ['possible', 'posible', 'possible', 'possible', 'possible', 'potential', 'possible', 'posible', 'potencial', 'posible', 'probable', 'posible', 'posible']
# Actual: t
#
# Predicted: it
# Prediction Synonyms:
# ['it', 'el', 'information', 'it']
# Actual: a
#
# Predicted: place
# Prediction Synonyms:
# ['place', 'lugar', 'topographic', 'spot', 'property', 'stead', 'position', 'lieu', 'shoes', 'home', 'position', 'post', 'berth', 'office', 'spot', 'billet', 'situation', 'position', 'station', 'seat', 'plaza', 'piazza', 'position', 'space', 'blank', 'put', 'set', 'pose', 'position', 'lay', 'rate', 'rank', 'range', 'order', 'grade', 'locate', 'site', 'come', 'come', 'target', 'aim', 'direct', 'point', 'identify', 'set', 'localize', 'localise', 'put', 'set', 'localize', 'localise', 'invest', 'put', 'commit', 'station', 'post', 'send', 'lugar', 'lugar', 'posición', 'puesto', 'sitio', 'colocación', 'emplazamiento', 'localización', 'lugar', 'posición', 'radicación', 'sitio', 'situación', 'ubicación', 'espacio', 'lugar', 'sitio', 'lugar', 'posición', 'lugar', 'parcela', 'propiedad', 'terreno', 'lugar', 'puesto', 'sitio', 'lugar', 'posición', 'lugar', 'sitio', 'lugar', 'sitio', 'lugar', 'distinción', 'lugar', 'posición', 'prestigio']
# Actual: so
#
# Predicted: heard
# Prediction Synonyms:
# ['heard', 'escuchado', 'hear', 'learn', 'hear', 'get', 'get', 'pick', 'find', 'get', 'discover', 'see', 'hear', 'try', 'hear', 'listen', 'hear', 'take']
# Actual: saw
#
# Predicted: ...
# Prediction Synonyms:
# ['', '']
# Actual: te
#
# Predicted: the
# Prediction Synonyms:
# ['the', 'el']
# Actual: in
#
# Predicted: caja
# Prediction Synonyms:
# ['caja', 'caja', 'caja', 'caja', 'caja', 'caja', 'caja', 'caja', 'cubierta', 'caja', 'caja']
# Actual: pic
#
# Predicted: que
# Prediction Synonyms:
# ['that', 'que']
# Actual: me
#
# Predicted: of
# Prediction Synonyms:
# ['of', 'de', 'de', 'delaware', 'estado', 'primer']
# Actual: of
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: lol
# Prediction Synonyms:
# ['lol', 'lol']
# Actual: ala
#
# Predicted: que
# Prediction Synonyms:
# ['that', 'que']
# Actual: que
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: Year?
# Prediction Synonyms:
# ['year', 'el año']
# Actual: weekend
#
# Predicted: the
# Prediction Synonyms:
# ['the', 'el']
# Actual: doing
#
# Predicted: this
# Prediction Synonyms:
# ['this', 'este', 'este']
# Actual: it
#
# Predicted: con
# Prediction Synonyms:
# ['with', 'con']
# Actual: para
#
# Predicted: Columbia,
# Prediction Synonyms:
# ['columbia', 'en colombia']
# Actual: and
#
# Predicted: do
# Prediction Synonyms:
# ['do', 'y lo', 'bash', 'brawl', 'doh', 'ut', 'doctor', 'do', 'make', 'perform', 'execute', 'perform', 'fare', 'make', 'come', 'get', 'cause', 'make', 'practice', 'practise', 'exercise', 'suffice', 'answer', 'serve', 'make', 'act', 'behave', 'serve', 'manage', 'dress', 'arrange', 'set', 'coif', 'coiffe', 'coiffure']
# Actual: hate
#
# Predicted: bellys,
# Prediction Synonyms:
# ['bellys', 'de bellas']
# Actual: de
#
# Predicted: Te
# Prediction Synonyms:
# ['te', 'te', 'tellurium', 'atomic', 'ti', 'te', 'si']
# Actual: agarre
#
# Predicted: be
# Prediction Synonyms:
# ['be', 'ser', 'beryllium', 'be', 'glucinium', 'atomic', 'exist', 'equal', 'constitute', 'represent', 'make', 'comprise', 'follow', 'embody', 'personify', 'live', 'cost', 'organismo', 'ser', 'organismo', 'ser', 'constituir', 'representar', 'equivaler', 'significar']
# Actual: be
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: haha
# Prediction Synonyms:
# ['haha', 'hahaha']
# Actual: se
#
# Predicted: over…
# Prediction Synonyms:
# ['over…', 'sobre']
# Actual: on
#
# Predicted: the
# Prediction Synonyms:
# ['the', 'el']
# Actual: the
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: si
# Prediction Synonyms:
# ['it is', 'si', 'si']
# Actual: bien
#
# Predicted: d
# Prediction Synonyms:
# ['d', 'd', 'vitamin', 'calciferol', 'viosterol', 'ergocalciferol', 'cholecalciferol', 'd', 'five', '500', 'd', 'd', 'five', '500', 'calciferol', 'colecalciferol', 'd', 'ergocalciferol', 'visoterol', 'vitamina', 'd']
# Actual: los
#
# Predicted: asleep
# Prediction Synonyms:
# ['asleep', 'sueño', 'benumbed', 'numb', 'at', 'at', 'deceased', 'departed', 'gone', 'quimera', 'sueño', 'sueño', 'ensueño', 'ilusión', 'utopía', 'ambición', 'aspiración', 'pretensión', 'cabezada', 'siesta']
# Actual: asleep
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: cortito
# Prediction Synonyms:
# ['cuted', 'cortado', 'cut', 'reduce', 'cut', 'cut', 'trim', 'trim', 'trim', 'cut', 'bring', 'swerve', 'sheer', 'curve', 'trend', 'veer', 'slue', 'slew', 'cut', 'cut', 'cut', 'cut', 'cut', 'tailor', 'cut', 'write', 'issue', 'make', 'cut', 'edit', 'cut', 'edit', 'cut', 'skip', 'hack', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'burn', 'cut', 'cut', 'cut', 'cut', 'cut', 'switch', 'cut', 'turn', 'turn', 'cut', 'cut', 'cut', 'ignore', 'disregard', 'snub', 'cut', 'cut', 'cut', 'prune', 'rationalize', 'rationalise', 'cut', 'cut', 'cut', 'cut', 'abridge', 'foreshorten', 'abbreviate', 'shorten', 'cut', 'contract', 'reduce', 'dilute', 'thin', 'thin', 'reduce', 'cut', 'cut', 'cut', 'geld', 'cut', 'cortado', 'recortado']
# Actual: notadoo
#
# Predicted: kasi
# Prediction Synonyms:
# ['by cas', 'casas']
# Actual: 3
#
# Predicted: que
# Prediction Synonyms:
# ['that', 'que']
# Actual: sick
#
# Predicted: ,
# Prediction Synonyms:
# ['', 'y', 'y']
# Actual: ni
#
# Predicted: day
# Prediction Synonyms:
# ['day', 'día', 'twentyfour', 'twentyfour', '24hour', 'solar', 'mean', 'daytime', 'daylight', 'sidereal', 'day', 'clarence', 'clarence', 'día', 'día', 'día', 'día', 'día', 'jornada', 'día']
# Actual: day
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: #Cyber
# Prediction Synonyms:
# ['#cyber', '#cyber']
# Actual: friend
#
# Predicted: in
# Prediction Synonyms:
# ['in', 'en', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward', 'en', 'tuerca']
# Actual: in
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: little
# Prediction Synonyms:
# ['little', 'pequeño', 'small', 'slight', 'small', 'fiddling', 'footling', 'lilliputian', 'niggling', 'piddling', 'piffling', 'petty', 'picayune', 'trivial', 'small', 'short', 'minuscule', 'small', 'pequeño', 'insignificante', 'pequeño', 'trivial', 'menudo', 'pequeño', 'pequeño', 'insignificante', 'pequeño', 'modesto', 'pequeño', 'escaso', 'pequeño', 'pequeño', 'humilde', 'modesto', 'pequeño', 'sencillo', 'menor', 'pequeña', 'pequeño']
# Actual: serious
#
# Predicted: nana
# Prediction Synonyms:
# ['nana', 'nana', 'abue', 'abuela', 'abuelita', 'nana', 'tata']
# Actual: padrino
#
# Predicted: dorar
# Prediction Synonyms:
# ['golded', 'dolores']
# Actual: a
#
# Predicted: jos
# Prediction Synonyms:
# ['if', 'si', 'si']
# Actual: signal
#
# Predicted: no
# Prediction Synonyms:
# ['no', 'no', 'nobelium', 'no', 'atomic', 'no', 'no']
# Actual: we
#
# Predicted: to
# Prediction Synonyms:
# ['to', 'para']
# Actual: to
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: in
# Prediction Synonyms:
# ['in', 'en', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward', 'en', 'tuerca']
# Actual: in
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: using
# Prediction Synonyms:
# ['using', 'uso de', 'exploitation', 'victimization', 'victimisation', 'use', 'utilize', 'utilise', 'apply', 'employ', 'use', 'habituate', 'use', 'expend', 'use', 'practice', 'apply', 'use', 'use']
# Actual: on
#
# Predicted:
# Prediction Synonyms:
# ['', '']
# Actual: >
#
# Predicted: of
# Prediction Synonyms:
# ['of', 'de', 'de', 'delaware', 'estado', 'primer']
# Actual: from
#
# Predicted: in
# Prediction Synonyms:
# ['in', 'en', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward', 'en', 'tuerca']
# Actual: in
# !!!!!!!!!MATCH FOUND!!!!!!!!!
#
# Predicted: pool
# Prediction Synonyms:
# ['pool', 'piscina', 'pond', 'consortium', 'syndicate', 'puddle', 'kitty', 'puddle', 'pocket', 'natatorio', 'pileta', 'piscina']
# Actual: super
#
# Predicted: a
# Prediction Synonyms:
# ['a', 'a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group', 'a']
# Actual: everything
#
# Predicted: .
# Prediction Synonyms:
# ['', '']
# Actual: useless
#
# Predicted: lng!
# Prediction Synonyms:
# ['the lng', '¡lng ¡']
# Actual: el
#
# Predicted:
# Prediction Synonyms:
# ['', '']
# Actual: podido
#
# Predicted: aside
# Prediction Synonyms:
# ['aside', 'aside', 'digression', 'excursus', 'divagation', 'parenthesis', 'away', 'apart', 'away', 'apart', 'by', 'away']
# Actual: aside
# !!!!!!!!!MATCH FOUND!!!!!!!!!

# %%
# print("Standard Metric Scores:")

# for score in scores:
#   print(score)
# print()

# %%
print("Synonym Metric Scores:")

for synonym_score in synonym_scores:
  print(synonym_score)
print()
# Out:
# Synonym Metric Scores:
# 0.21739130434782608
# 0.12987012987012986
# 0.1839080459770115
