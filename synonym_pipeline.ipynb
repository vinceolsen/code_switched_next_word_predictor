# %% [markdown]
# <a href="https://colab.research.google.com/github/mnbpdx/code_switched_next_word_predictor/blob/main/synonym_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Full Synonym Pipeline

# %% [markdown]
# ## Synonym Pipeline Steps, Explained
#
# 1. Pass the predicted next word to a pre-trained language recognition model to **determine the language** of the word (one of the two languages in our mixed, code-switched corpus.)
# 2. **Translate** the predicted next word into the other language by passing it into an appropriate translation model.
# 3. **Get n synonyms** of predicted next word in both languages using cosine distance between word embeddings, gathered from two vector embedding models, one in each language. This could also be done by a GPT-3 model.
# 4. **Score the model** based on whether or not the actual next word is in the list of predicted next word bilingual synonyms.

# %% [markdown]
# ## Imports/Downloads

# %%
# !pip install -U easynmt
# !pip install sacremoses # was told to install this by a warning

from easynmt import EasyNMT
import nltk
from nltk.corpus import wordnet as wn

nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting easynmt
#   Downloading EasyNMT-2.0.2.tar.gz (23 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from easynmt) (4.64.1)
# Collecting transformers<5,>=4.4
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 5.6 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from easynmt) (1.13.0+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from easynmt) (1.21.6)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from easynmt) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 65.7 MB/s
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 7.2 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.8/dist-packages (from easynmt) (3.19.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->easynmt) (4.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (21.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 62.3 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 105.0 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers<5,>=4.4->easynmt) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers<5,>=4.4->easynmt) (3.0.9)
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from fasttext->easynmt) (57.4.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->easynmt) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->easynmt) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<5,>=4.4->easynmt) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<5,>=4.4->easynmt) (3.0.4)
# Building wheels for collected packages: easynmt, fasttext
#   Building wheel for easynmt (setup.py) ... done
#   Created wheel for easynmt: filename=EasyNMT-2.0.2-py3-none-any.whl size=19917 sha256=2e76ed3b104144faf00f3f17b0a0494aca3e90118e8edb06423ed3550e33a646
#   Stored in directory: /root/.cache/pip/wheels/4d/9b/b5/44756a28f050e4e7835b959e90998b42985db542f3153cce26
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp38-cp38-linux_x86_64.whl size=3133856 sha256=aaff977dee124cfe91e7f93ed35350cbfda0c534d1dd3a692d37d8a9ed69e474
#   Stored in directory: /root/.cache/pip/wheels/93/61/2a/c54711a91c418ba06ba195b1d78ff24fcaad8592f2a694ac94
# Successfully built easynmt fasttext
# Installing collected packages: tokenizers, pybind11, huggingface-hub, transformers, sentencepiece, fasttext, easynmt
# Successfully installed easynmt-2.0.2 fasttext-0.9.2 huggingface-hub-0.11.1 pybind11-2.10.1 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.25.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 4.0 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from sacremoses) (2022.6.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sacremoses) (4.64.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=b97c351e02b28384e117a57dc3a7702e69766c621feeaa4b7a9739f8bf90a7fe
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.0.53
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# ## Utility Functions

# %%
def langs_are_valid(lang1, lang2):
  if lang1 != 'en' and lang1 != 'es':
    print('Langugage must be either Spanish or English.')
    return False
  
  if lang2 != 'en' and lang2 != 'es':
    print('Langugage must be either Spanish or English.')
    return False

  return True

# %%
def strip_formatting(word: str) -> str:
    word = word.lower()
    word = word.strip()
    word = word.replace('.', '')
    word = word.replace(',', '')
    word = word.replace('-', '')
    word = word.replace('_', '')
    word = word.replace('!', '')
    word = word.replace('?', '')
    return word

# %% [markdown]
# ## Pipeline

# %% [markdown]
# ### Synonym Evaluation Metric

# %%
# Synonym gatherer code is modified from: https://github.com/johnbumgarner/synonyms_discovery_aggregation

def score_with_synonym_list(predictions, actual, lang1, lang2):
  if not langs_are_valid(lang1, lang2):
    raise Exception('Please use valid EasyNMT language strings.') # idk how to use exceptions in python, someone tell me if this is wrong

  translation_model = EasyNMT('m2m_100_418M')

  synonym_lists = []
  scores = []

  predictions = [strip_formatting(prediction) for prediction in predictions]
  actual = [strip_formatting(a) for a in actual]

  for word in predictions:

    if (lang1 != lang2):
      # Translate word into first language
      word_in_lang1 = translation_model.translate(word, target_lang=lang1)
      word_in_lang1 = strip_formatting(word_in_lang1)

      # Translate word into the OTHER language
      word_in_lang2 = translation_model.translate(word, target_lang=lang2)
      word_in_lang2 = strip_formatting(word_in_lang2)
    else:
       word_in_lang1 = word

    if (lang1 == 'en'):
      wn_lang1 = 'eng'
      wn_lang2 = 'spa'
    else:
      wn_lang1 = 'spa'
      wn_lang2 = 'eng'

    # Get synonym lists for word and translated_word

    synonyms = []

    # add the predicted word (and translation) to the synonym list
    synonyms.append(word_in_lang1)
    if (lang1 != lang2):
      synonyms.append(word_in_lang2)

    # add synonyms of word in lang1
    for synonym in wn.synsets(word_in_lang1, lang=wn_lang1):
      for item in synonym.lemmas(wn_lang1):
          if item.name() != word_in_lang1:
              formatted = strip_formatting(item.name().split('_')[0])
              synonyms.append(formatted)

    if (lang1 != lang2):
      # add synonyms of word in lang2
      for synonym in wn.synsets(word_in_lang2, lang=wn_lang2):
        for item in synonym.lemmas(wn_lang2):
            if item.name() != word_in_lang2:
              formatted = strip_formatting(item.name().split('_')[0])
              synonyms.append(formatted)

    # Throw all the discovered synonyms (and word & translated_word) onto synonym_lists
    synonym_lists.append(synonyms)

  # Compare synonym lists to actual
  match_found = False
  for predicted_word, actual_word, synonyms in zip(predictions, actual, synonym_lists):
    print()
    print("Predicted Word: " + predicted_word)
    print("Prediction Synonyms:")
    print(synonyms)
    print("Actual Word: " + actual_word)
    if actual_word in synonyms:
      match_found = True
      print("MATCH FOUND!")
    else:
      match_found = False
    scores.append(match_found)

  # Calculate and return metric
  return sum(scores) / len(scores)

# %% [markdown]
# ### Standard Evaluation Metric
#
# For comparison.

# %%
# Standard Evaluation Metric
def score_with_actual_word(predictions, actual):
  scores = []


  for prediction, actual in zip(predictions, actual):
    if strip_formatting(prediction) == strip_formatting(actual):
      scores.append(True)
    else:
      scores.append(False)

  return sum(scores) / len(scores)

# %%
# Sample Prediction

# predictions = ['pizza', 'turkey', 'baño', 'book', 'manzana', 'tiger']
# actual =    ['whale', 'chicken', 'bathroom', 'libro', 'plátano', 'tiger']

# score_with_synonym_list(predictions, actual, 'en', 'es')
# score_with_actual_word(predictions, actual)

# %% [markdown]
# ## Score GPT-3 Responses
#
# To run this on GPT-3 Responses from `code_switched_language_modeling_performance_evaluation.ipynb`, change `standard_results_path` to reflect the path of `standard_perfromance.json`.
#
# Alternatively, if you're running in Google Colab, simply drop `standard_perfromance.json` into the "Files" section of Google Colab and leave `standard_results_path` as '/content/standard_perfromance.json'.

# %%
import json

standard_results = dict()

standard_results_path = '/content/standard_perfromance.json'
with open(standard_results_path) as json_file:
    standard_results = json.load(json_file)

# pprint(standard_results)

if standard_results:
    print('Standard results loaded')
else:
     print('Standard results not loaded')
# Out:
# Standard results loaded

# %%
prediction_lists = []
actual_lists = []

for corpus in range(3):
  predictions = []
  actual = []
  for input_and_response in standard_results[corpus][1]:
    predictions.append(input_and_response[1][1])
    actual.append(input_and_response[0][4])
  prediction_lists.append(predictions)
  actual_lists.append(actual)

# %%
len(prediction_lists[0])
# Out:
# 92

# %% [markdown]
# ### Scores

# %%
# Standard Metric Scores

scores = []

for corpus in range(3):
  scores.append(score_with_actual_word(prediction_lists[corpus], actual_lists[corpus]))

# %%
# Synonym Metric Scores

synonym_scores = []

synonym_scores.append(score_with_synonym_list(prediction_lists[0], actual_lists[0], 'en', 'en'))
synonym_scores.append(score_with_synonym_list(prediction_lists[1], actual_lists[1], 'es', 'es'))
synonym_scores.append(score_with_synonym_list(prediction_lists[2], actual_lists[2], 'en', 'es'))
# Out:
# 89.9kB [00:00, 34.1MB/s]
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/272 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# Predicted Word: i
# Prediction Synonyms:
# ['i', 'iodine', 'iodin', 'i', 'atomic', 'one', '1', 'i', 'ace', 'single', 'unity', 'i', 'one', '1', 'ane']
# Actual Word: i
# MATCH FOUND!
#
# Predicted Word: the
# Prediction Synonyms:
# ['the']
# Actual Word: @slackerradio
#
# Predicted Word: do
# Prediction Synonyms:
# ['do', 'bash', 'brawl', 'doh', 'ut', 'doctor', 'do', 'make', 'perform', 'execute', 'perform', 'fare', 'make', 'come', 'get', 'cause', 'make', 'practice', 'practise', 'exercise', 'suffice', 'answer', 'serve', 'make', 'act', 'behave', 'serve', 'manage', 'dress', 'arrange', 'set', 'coif', 'coiffe', 'coiffure']
# Actual Word: rock
#
# Predicted Word: (ps
# Prediction Synonyms:
# ['(ps']
# Actual Word: i
#
# Predicted Word: be
# Prediction Synonyms:
# ['be', 'beryllium', 'be', 'glucinium', 'atomic', 'exist', 'equal', 'constitute', 'represent', 'make', 'comprise', 'follow', 'embody', 'personify', 'live', 'cost']
# Actual Word: bee
#
# Predicted Word: for
# Prediction Synonyms:
# ['for']
# Actual Word: for
# MATCH FOUND!
#
# Predicted Word: mixing
# Prediction Synonyms:
# ['mixing', 'mix', 'commixture', 'admixture', 'mixture', 'intermixture', 'blend', 'flux', 'mix', 'conflate', 'commingle', 'immix', 'fuse', 'coalesce', 'meld', 'combine', 'merge', 'desegregate', 'integrate', 'mix', 'mix', 'mix', 'mix', 'mix', 'mingle', 'commix', 'unify', 'amalgamate', 'shuffle', 'ruffle', 'mix']
# Actual Word: though
#
# Predicted Word: sunday
# Prediction Synonyms:
# ['sunday', 'sunday', "lord's", 'dominicus', 'sun', 'sunday', 'billy', 'william']
# Actual Word: bowl
#
# Predicted Word: to
# Prediction Synonyms:
# ['to']
# Actual Word: to
# MATCH FOUND!
#
# Predicted Word: was
# Prediction Synonyms:
# ['was', 'washington', 'evergreen', 'wa', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual Word: was
# MATCH FOUND!
#
# Predicted Word: your
# Prediction Synonyms:
# ['your']
# Actual Word: nothing
#
# Predicted Word: for
# Prediction Synonyms:
# ['for']
# Actual Word: would
#
# Predicted Word: |
# Prediction Synonyms:
# ['|']
# Actual Word: http://twitpiccom/10tti2
#
# Predicted Word: make
# Prediction Synonyms:
# ['make', 'brand', 'shuffle', 'shuffling', 'do', 'get', 'create', 'induce', 'stimulate', 'cause', 'have', 'get', 'cause', 'do', 'produce', 'create', 'draw', 'create', 'gain', 'take', 'clear', 'earn', 'realize', 'realise', 'pull', 'bring', 'do', 'form', 'constitute', 'reach', 'get', 'progress', 'construct', 'build', 'name', 'nominate', 'have', 'get', 'reach', 'attain', 'hit', 'arrive', 'gain', 'lay', 'establish', 'hold', 'throw', 'have', 'give', 'make', 'take', 'stool', 'defecate', 'shit', 'take', 'take', 'caca', 'crap', 'work', 'cook', 'fix', 'ready', 'prepare', 'seduce', 'score', 'pretend', 'make', 'urinate', 'piddle', 'puddle', 'micturate', 'piss', 'pee', 'peepee', 'make', 'relieve', 'take', 'spend', 'wee', 'weewee', 'pass']
# Actual Word: leave
#
# Predicted Word: live
# Prediction Synonyms:
# ['live', 'populate', 'dwell', 'inhabit', 'survive', 'last', 'live', 'go', 'endure', 'hold', 'hold', 'exist', 'survive', 'subsist', 'be', 'know', 'experience', 'unrecorded', 'alive', 'bouncy', 'lively', 'resilient', 'springy', 'hot', 'alive']
# Actual Word: love
#
# Predicted Word: why
# Prediction Synonyms:
# ['why', 'wherefore']
# Actual Word: why
# MATCH FOUND!
#
# Predicted Word: after
# Prediction Synonyms:
# ['after', 'subsequently', 'later', 'afterwards', 'afterward', 'later']
# Actual Word: before
#
# Predicted Word: http…
# Prediction Synonyms:
# ['http…']
# Actual Word: may
#
# Predicted Word: hahhaa
# Prediction Synonyms:
# ['hahhaa']
# Actual Word: ha
#
# Predicted Word: the
# Prediction Synonyms:
# ['the']
# Actual Word: my
#
# Predicted Word: one
# Prediction Synonyms:
# ['one', '1', 'i', 'ace', 'single', 'unity', '1', 'i', 'ane', 'unitary', 'matchless', 'nonpareil', 'one', 'peerless', 'unmatched', 'unmatchable', 'unrivaled', 'unrivalled']
# Actual Word: feature
#
# Predicted Word: car
# Prediction Synonyms:
# ['car', 'auto', 'automobile', 'machine', 'motorcar', 'railcar', 'railway', 'railroad', 'gondola', 'elevator', 'cable']
# Actual Word: old
#
# Predicted Word: in
# Prediction Synonyms:
# ['in', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward']
# Actual Word: in
# MATCH FOUND!
#
# Predicted Word: 4
# Prediction Synonyms:
# ['4', 'four', 'iv', 'tetrad', 'quatern', 'quaternion', 'quaternary', 'quaternity', 'quartet', 'quadruplet', 'foursome', 'little', 'four', 'iv']
# Actual Word: please
#
# Predicted Word: is
# Prediction Synonyms:
# ['is', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual Word: is
# MATCH FOUND!
#
# Predicted Word: free
# Prediction Synonyms:
# ['free', 'free', 'liberate', 'release', 'unloose', 'unloosen', 'loose', 'rid', 'disembarrass', 'dislodge', 'exempt', 'relieve', 'release', 'discharge', 'disengage', 'absolve', 'justify', 'release', 'relinquish', 'resign', 'give', 'release', 'liberate', 'unblock', 'unfreeze', 'release', 'complimentary', 'costless', 'gratis', 'gratuitous', 'detached', 'spare', 'barren', 'destitute', 'devoid', 'innocent', 'loose', 'liberal', 'loose']
# Actual Word: songs
#
# Predicted Word: and
# Prediction Synonyms:
# ['and']
# Actual Word: delivered
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: in
#
# Predicted Word: and
# Prediction Synonyms:
# ['and']
# Actual Word: with
#
# Predicted Word: wonderland
# Prediction Synonyms:
# ['wonderland']
# Actual Word: curious
#
# Predicted Word: labelprod
# Prediction Synonyms:
# ['labelprod']
# Actual Word: bloggerslets
#
# Predicted Word: too
# Prediction Synonyms:
# ['too', 'excessively', 'overly', 'to', 'besides', 'also', 'likewise', 'as']
# Actual Word: to
# MATCH FOUND!
#
# Predicted Word: appearing
# Prediction Synonyms:
# ['appearing', 'appearance', 'coming', 'look', 'appear', 'seem', 'appear', 'appear', 'come', 'appear', 'seem', 'appear', 'come', 'appear', 'appear']
# Actual Word: multiple
#
# Predicted Word: the
# Prediction Synonyms:
# ['the']
# Actual Word: the
# MATCH FOUND!
#
# Predicted Word: on
# Prediction Synonyms:
# ['on', 'along']
# Actual Word: yung
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: personal
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: for
#
# Predicted Word: the
# Prediction Synonyms:
# ['the']
# Actual Word: a
#
# Predicted Word: chandelier
# Prediction Synonyms:
# ['chandelier', 'pendant', 'pendent']
# Actual Word: may
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: modern
#
# Predicted Word: dig
# Prediction Synonyms:
# ['dig', 'excavation', 'archeological', 'shot', 'shaft', 'slam', 'barb', 'jibe', 'gibe', 'excavation', 'digging', 'jab', 'delve', 'cut', 'turn', 'dig', 'labor', 'labour', 'toil', 'fag', 'travail', 'grind', 'drudge', 'moil', 'dig', 'dig', 'excavate', 'hollow', 'jab', 'prod', 'stab', 'poke', 'grok', 'get', 'comprehend', 'savvy', 'grasp', 'compass', 'apprehend']
# Actual Word: read
#
# Predicted Word: more
# Prediction Synonyms:
# ['more', 'more', 'thomas', 'sir', 'more', 'to']
# Actual Word: #friendsthemovie
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: and
#
# Predicted Word: i
# Prediction Synonyms:
# ['i', 'iodine', 'iodin', 'i', 'atomic', 'one', '1', 'i', 'ace', 'single', 'unity', 'i', 'one', '1', 'ane']
# Actual Word: prep
#
# Predicted Word: with
# Prediction Synonyms:
# ['with']
# Actual Word: with
# MATCH FOUND!
#
# Predicted Word: it
# Prediction Synonyms:
# ['it', 'information', 'it']
# Actual Word: home
#
# Predicted Word: a
# Prediction Synonyms:
# ['a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group']
# Actual Word: tweet
#
# Predicted Word: must
# Prediction Synonyms:
# ['must', 'mustiness', 'moldiness']
# Actual Word: remain
#
# Predicted Word: :s
# Prediction Synonyms:
# [':s']
# Actual Word: sleephmmm
#
# Predicted Word: him
# Prediction Synonyms:
# ['him']
# Actual Word: for
#
# Predicted Word: $799
# Prediction Synonyms:
# ['$799']
# Actual Word: 2/10
#
# Predicted Word: not
# Prediction Synonyms:
# ['not', 'non']
# Actual Word: confusedare
#
# Predicted Word: to
# Prediction Synonyms:
# ['to']
# Actual Word: bottle
#
# Predicted Word: to
# Prediction Synonyms:
# ['to']
# Actual Word: to
# MATCH FOUND!
#
# Predicted Word: being
# Prediction Synonyms:
# ['being', 'beingness', 'existence', 'organism', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual Word: to
#
# Predicted Word: but
# Prediction Synonyms:
# ['but', 'merely', 'simply', 'just', 'only']
# Actual Word: but
# MATCH FOUND!
#
# Predicted Word: :
# Prediction Synonyms:
# [':']
# Actual Word: http://owly/14ljw
#
# Predicted Word: hotel
# Prediction Synonyms:
# ['hotel']
# Actual Word: house
#
# Predicted Word: the
# Prediction Synonyms:
# ['the']
# Actual Word: london
#
# Predicted Word: well
# Prediction Synonyms:
# ['well', 'wellspring', 'fountainhead', 'swell', 'good', 'good', 'easily', 'considerably', 'substantially', 'intimately', 'advantageously', 'comfortably']
# Actual Word: a
#
# Predicted Word: 5
# Prediction Synonyms:
# ['5', 'five', 'v', 'cinque', 'quint', 'quintet', 'fivesome', 'quintuplet', 'pentad', 'fin', 'phoebe', 'little', 'five', 'v']
# Actual Word: will
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: ;d
#
# Predicted Word: winning
# Prediction Synonyms:
# ['winning', 'win', 'acquire', 'win', 'gain', 'gain', 'advance', 'win', 'pull', 'make', 'get', 'gain', 'succeed', 'win', 'come', 'bring', 'deliver', 'victorious', 'fetching', 'taking']
# Actual Word: winning
# MATCH FOUND!
#
# Predicted Word: at
# Prediction Synonyms:
# ['at', 'astatine', 'at', 'atomic']
# Actual Word: at
# MATCH FOUND!
#
# Predicted Word: "colferiacs"
# Prediction Synonyms:
# ['"colferiacs"']
# Actual Word: as
#
# Predicted Word: face
# Prediction Synonyms:
# ['face', 'human', 'expression', 'look', 'aspect', 'facial', 'side', 'grimace', 'font', 'fount', 'typeface', 'case', 'boldness', 'nerve', 'brass', 'cheek', 'confront', 'face', 'confront', 'front', 'look', 'confront', 'present']
# Actual Word: face
# MATCH FOUND!
#
# Predicted Word: see
# Prediction Synonyms:
# ['see', 'understand', 'realize', 'realise', 'witness', 'find', 'visualize', 'visualise', 'envision', 'project', 'fancy', 'figure', 'picture', 'image', 'consider', 'reckon', 'view', 'regard', 'learn', 'hear', 'get', 'get', 'pick', 'find', 'get', 'discover', 'watch', 'view', 'catch', 'take', 'meet', 'run', 'encounter', 'run', 'come', 'determine', 'check', 'find', 'ascertain', 'watch', 'learn', 'check', 'insure', 'see', 'ensure', 'control', 'ascertain', 'assure', 'visit', 'attend', 'take', 'look', 'go', 'go', 'date', 'examine', 'experience', 'go', 'escort', 'interpret', 'construe']
# Actual Word: see
# MATCH FOUND!
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: zhanghuangbin
#
# Predicted Word: with
# Prediction Synonyms:
# ['with']
# Actual Word: with
# MATCH FOUND!
#
# Predicted Word: have
# Prediction Synonyms:
# ['have', 'rich', 'wealthy', 'have', 'hold', 'feature', 'experience', 'receive', 'get', 'own', 'possess', 'get', 'let', 'consume', 'ingest', 'take', 'take', 'hold', 'throw', 'make', 'give', 'experience', 'induce', 'stimulate', 'cause', 'get', 'make', 'accept', 'take', 'receive', 'suffer', 'sustain', 'get', 'get', 'make', 'give', 'deliver', 'bear', 'birth', 'take']
# Actual Word: you
#
# Predicted Word: :)
# Prediction Synonyms:
# [':)']
# Actual Word: a
#
# Predicted Word: only
# Prediction Synonyms:
# ['only', 'lone', 'lonesome', 'sole', 'solitary', 'alone', 'merely', 'simply', 'just', 'but', 'entirely', 'exclusively', 'solely', 'alone', 'only', 'only']
# Actual Word: going
#
# Predicted Word: :
# Prediction Synonyms:
# [':']
# Actual Word: 20
#
# Predicted Word: to
# Prediction Synonyms:
# ['to']
# Actual Word: to
# MATCH FOUND!
#
# Predicted Word: i
# Prediction Synonyms:
# ['i', 'iodine', 'iodin', 'i', 'atomic', 'one', '1', 'i', 'ace', 'single', 'unity', 'i', 'one', '1', 'ane']
# Actual Word: i
# MATCH FOUND!
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: or
#
# Predicted Word: more
# Prediction Synonyms:
# ['more', 'more', 'thomas', 'sir', 'more', 'to']
# Actual Word: still
#
# Predicted Word: a
# Prediction Synonyms:
# ['a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group']
# Actual Word: black
#
# Predicted Word: )
# Prediction Synonyms:
# [')']
# Actual Word: live
#
# Predicted Word: sounds
# Prediction Synonyms:
# ['sounds', 'sound', 'sound', 'auditory', 'sound', 'sound', 'audio', 'sound', 'phone', 'speech', 'sound', 'strait', 'sound', 'sound', 'sound', 'sound', 'go', 'sound', 'sound', 'voice', 'sound', 'vocalize', 'vocalise', 'sound', 'fathom', 'sound']
# Actual Word: cant
#
# Predicted Word: @nogikakiko:
# Prediction Synonyms:
# ['@nogikakiko:']
# Actual Word: @shimay
#
# Predicted Word: a
# Prediction Synonyms:
# ['a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group']
# Actual Word: right
#
# Predicted Word: not
# Prediction Synonyms:
# ['not', 'non']
# Actual Word: not
# MATCH FOUND!
#
# Predicted Word: heartbrokenbut
# Prediction Synonyms:
# ['heartbrokenbut']
# Actual Word: smootha
#
# Predicted Word: she
# Prediction Synonyms:
# ['she']
# Actual Word: carmen
#
# Predicted Word: st
# Prediction Synonyms:
# ['st']
# Actual Word: st
# MATCH FOUND!
#
# Predicted Word: was
# Prediction Synonyms:
# ['was', 'washington', 'evergreen', 'wa', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual Word: mondayfriday
#
# Predicted Word: on
# Prediction Synonyms:
# ['on', 'along']
# Actual Word: for
#
# Predicted Word: did)
# Prediction Synonyms:
# ['did)']
# Actual Word: had
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: this
#
# Predicted Word: a
# Prediction Synonyms:
# ['a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group']
# Actual Word: more
#
# Predicted Word: and
# Prediction Synonyms:
# ['and']
# Actual Word: to
#
# Predicted Word: #2017
# Prediction Synonyms:
# ['#2017']
# Actual Word: urbana
#
# Predicted Word: competición
# Prediction Synonyms:
# ['competición', 'competencia', 'contienda', 'rivalidad', 'campeonato', 'certamen', 'concurso', 'contienda', 'prueba', 'adversario', 'competidor', 'contendiente', 'contrincante', 'rival', 'competencia']
# Actual Word: cuestión
#
# Predicted Word: patria…
# Prediction Synonyms:
# ['patria…']
# Actual Word: juventud
#
# Predicted Word: de
# Prediction Synonyms:
# ['de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: sin
#
# Predicted Word: y
# Prediction Synonyms:
# ['y', 'y']
# Actual Word: 40
#
# Predicted Word: que
# Prediction Synonyms:
# ['que']
# Actual Word: mostrona
#
# Predicted Word: https://tco/nxopy
# Prediction Synonyms:
# ['https://tco/nxopy']
# Actual Word: http://tco/7ey68fo2qm
#
# Predicted Word: http://wwwpolllaxocom
# Prediction Synonyms:
# ['http://wwwpolllaxocom']
# Actual Word: http://tco/7ey68fo2qm
#
# Predicted Word: 💫🦢
# Prediction Synonyms:
# ['💫🦢']
# Actual Word: en
#
# Predicted Word: y
# Prediction Synonyms:
# ['y', 'y']
# Actual Word: de
#
# Predicted Word: @tveslove
# Prediction Synonyms:
# ['@tveslove']
# Actual Word: @glorsl
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: ante
#
# Predicted Word: el
# Prediction Synonyms:
# ['el']
# Actual Word: quien
#
# Predicted Word: información
# Prediction Synonyms:
# ['información', 'aviso', 'consejo', 'filtración', 'idea', 'indicación', 'información', 'ventaja', 'denuncia']
# Actual Word: vida
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: que
#
# Predicted Word: @smurffdeoro
# Prediction Synonyms:
# ['@smurffdeoro']
# Actual Word: l
#
# Predicted Word: no
# Prediction Synonyms:
# ['no']
# Actual Word: nunca
#
# Predicted Word: de
# Prediction Synonyms:
# ['de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: de
# MATCH FOUND!
#
# Predicted Word: bueno
# Prediction Synonyms:
# ['bueno', 'buen', 'bien', 'sano', 'serio', 'alegre', 'contento', 'feliz', 'buen', 'buen', 'ideal', 'idóneo', 'correcto', 'abundante', 'nutritivo', 'sólido', 'bien']
# Actual Word: no
#
# Predicted Word: a
# Prediction Synonyms:
# ['a', 'a']
# Actual Word: llenando
#
# Predicted Word: ayudando
# Prediction Synonyms:
# ['ayudando']
# Actual Word: buscando
#
# Predicted Word: de
# Prediction Synonyms:
# ['de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: funciona
#
# Predicted Word: ea
# Prediction Synonyms:
# ['ea']
# Actual Word: puede
#
# Predicted Word: luna
# Prediction Synonyms:
# ['luna', 'luna']
# Actual Word: luna
# MATCH FOUND!
#
# Predicted Word: —
# Prediction Synonyms:
# ['—']
# Actual Word: jajaja
#
# Predicted Word: de
# Prediction Synonyms:
# ['de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: en
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: @1313fran
#
# Predicted Word: especialarme
# Prediction Synonyms:
# ['especialarme']
# Actual Word: comer
#
# Predicted Word: tienes
# Prediction Synonyms:
# ['tienes']
# Actual Word: dios
#
# Predicted Word: sabia
# Prediction Synonyms:
# ['sabia']
# Actual Word: hace
#
# Predicted Word: fer1xx
# Prediction Synonyms:
# ['fer1xx']
# Actual Word: josé
#
# Predicted Word: ley
# Prediction Synonyms:
# ['ley', 'ley', 'acta', 'estatuto', 'jurisprudencia']
# Actual Word: mujer
#
# Predicted Word: me
# Prediction Synonyms:
# ['me']
# Actual Word: se
#
# Predicted Word: conceda
# Prediction Synonyms:
# ['conceda']
# Actual Word: haga
#
# Predicted Word: expresión
# Prediction Synonyms:
# ['expresión', 'apariencia', 'aspecto', 'estampa', 'forma', 'representación', 'fórmula', 'manifestación', 'reflejo', 'forma', 'giro', 'juego', 'emisión', 'enunciado', 'locución']
# Actual Word: arrogancia
#
# Predicted Word: no
# Prediction Synonyms:
# ['no']
# Actual Word: no
# MATCH FOUND!
#
# Predicted Word: get
# Prediction Synonyms:
# ['get']
# Actual Word: feel
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: https://tco/jscmhiu1gh
#
# Predicted Word: podido
# Prediction Synonyms:
# ['podido']
# Actual Word: probado
#
# Predicted Word: coceaba
# Prediction Synonyms:
# ['coceaba']
# Actual Word: es
#
# Predicted Word: gente
# Prediction Synonyms:
# ['gente', 'personas', 'pueblo', 'masa', 'multitud', 'pueblo']
# Actual Word: media
#
# Predicted Word: la
# Prediction Synonyms:
# ['la']
# Actual Word: la
# MATCH FOUND!
#
# Predicted Word: en
# Prediction Synonyms:
# ['en', 'tuerca']
# Actual Word: con
#
# Predicted Word: mejor
# Prediction Synonyms:
# ['mejor', 'lo']
# Actual Word: el
#
# Predicted Word: no
# Prediction Synonyms:
# ['no']
# Actual Word: 😍
#
# Predicted Word: no
# Prediction Synonyms:
# ['no']
# Actual Word: es
#
# Predicted Word: te
# Prediction Synonyms:
# ['te']
# Actual Word: la
#
# Predicted Word: onu:
# Prediction Synonyms:
# ['onu:']
# Actual Word: onu
#
# Predicted Word: estés
# Prediction Synonyms:
# ['estés']
# Actual Word: te
#
# Predicted Word: y
# Prediction Synonyms:
# ['y', 'y']
# Actual Word: en
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: lo
#
# Predicted Word: de
# Prediction Synonyms:
# ['de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: de
# MATCH FOUND!
#
# Predicted Word: negro
# Prediction Synonyms:
# ['negro', 'desalentador', 'oscuro', 'triste', 'oscuro', 'perverso', 'siniestro', 'sombrío']
# Actual Word: soy
#
# Predicted Word: magistra…0
# Prediction Synonyms:
# ['magistra…0']
# Actual Word: magistratura
#
# Predicted Word: lo
# Prediction Synonyms:
# ['lo']
# Actual Word: collado
#
# Predicted Word: a
# Prediction Synonyms:
# ['a', 'a']
# Actual Word: no
#
# Predicted Word: que
# Prediction Synonyms:
# ['que']
# Actual Word: de
#
# Predicted Word: de
# Prediction Synonyms:
# ['de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: de
# MATCH FOUND!
#
# Predicted Word: quien
# Prediction Synonyms:
# ['quien']
# Actual Word: quien
# MATCH FOUND!
#
# Predicted Word: usar
# Prediction Synonyms:
# ['usar', 'acabar', 'agotar', 'utilizar', 'emplear', 'utilizar', 'utilizar', 'aplicar', 'practicar']
# Actual Word: ponerle
#
# Predicted Word: perfecto
# Prediction Synonyms:
# ['perfecto', 'absoluto', 'completo', 'puro', 'total', 'absoluto', 'completo', 'total', 'exacto', 'preciso']
# Actual Word: fácil
#
# Predicted Word: nada
# Prediction Synonyms:
# ['nada', 'cero']
# Actual Word: nada
# MATCH FOUND!
#
# Predicted Word: perseguido
# Prediction Synonyms:
# ['perseguido']
# Actual Word: el
#
# Predicted Word: de
# Prediction Synonyms:
# ['de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: la
#
# Predicted Word: a
# Prediction Synonyms:
# ['a', 'a']
# Actual Word: a
# MATCH FOUND!
#
# Predicted Word:
# Prediction Synonyms:
# ['']
# Actual Word: en
#
# Predicted Word: rastafaris
# Prediction Synonyms:
# ['rastafaris']
# Actual Word: si
#
# Predicted Word: y
# Prediction Synonyms:
# ['y', 'y']
# Actual Word: no
#
# Predicted Word: que
# Prediction Synonyms:
# ['que']
# Actual Word: como
#
# Predicted Word: stéfano
# Prediction Synonyms:
# ['stéfano']
# Actual Word: stéfano
# MATCH FOUND!
#
# Predicted Word: esas…
# Prediction Synonyms:
# ['esas…']
# Actual Word: esos
#
# Predicted Word: ~~~
# Prediction Synonyms:
# ['~~~']
# Actual Word: —en
#
# Predicted Word: watch
# Prediction Synonyms:
# ['watch']
# Actual Word: el
#
# Predicted Word: frente
# Prediction Synonyms:
# ['frente', 'cabeza', 'primer', 'primera', 'vanguardia', 'presencia']
# Actual Word: tres
#
# Predicted Word: hombres
# Prediction Synonyms:
# ['hombres']
# Actual Word: te
#
# Predicted Word: q
# Prediction Synonyms:
# ['q', 'q']
# Actual Word: buen
#
# Predicted Word: la
# Prediction Synonyms:
# ['la']
# Actual Word: pasar
# 100%|██████████| 938k/938k [00:00<00:00, 1.08MB/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.8/dist-packages/transformers/generation/utils.py:1387: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 200 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Predicted Word: )
# Prediction Synonyms:
# [')', ')']
# Actual Word: y
#
# Predicted Word: y
# Prediction Synonyms:
# ['and', 'y', 'y']
# Actual Word: lea
#
# Predicted Word: ie:
# Prediction Synonyms:
# ['it is:', 'es que:']
# Actual Word: cuñadas
#
# Predicted Word: an
# Prediction Synonyms:
# ['an', 'una', 'associate', 'an']
# Actual Word: the
#
# Predicted Word: we
# Prediction Synonyms:
# ['we', 'nosotros']
# Actual Word: we
# MATCH FOUND!
#
# Predicted Word: what
# Prediction Synonyms:
# ['what', '¿qué']
# Actual Word: it's
#
# Predicted Word: afectan
# Prediction Synonyms:
# ['affected', 'afectan', 'affect', 'impact', 'bear', 'bear', 'touch', 'touch', 'affect', 'involve', 'affect', 'regard', 'feign', 'sham', 'pretend', 'affect', 'dissemble', 'affect', 'impress', 'move', 'strike', 'unnatural', 'moved', 'stirred', 'touched']
# Actual Word: te
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: fuck
#
# Predicted Word: ien
# Prediction Synonyms:
# ['the nine', 'el neno']
# Actual Word: ay
#
# Predicted Word: is
# Prediction Synonyms:
# ['is', 'es', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual Word: is
# MATCH FOUND!
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: i’m
#
# Predicted Word: really
# Prediction Synonyms:
# ['really', 'realmente', 'truly', 'genuinely', 'actually', 'in', 'truly', 'very', 'real', 'rattling']
# Actual Word: como
#
# Predicted Word: his
# Prediction Synonyms:
# ['his', 'su']
# Actual Word: her
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: del
#
# Predicted Word: was
# Prediction Synonyms:
# ['was', 'fue', 'washington', 'evergreen', 'wa', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
# Actual Word: andaba
#
# Predicted Word: great
# Prediction Synonyms:
# ['great', 'gran', 'outstanding', 'bangup', 'bully', 'corking', 'cracking', 'dandy', 'groovy', 'keen', 'neat', 'nifty', 'not', 'peachy', 'slapup', 'swell', 'smashing', 'capital', 'majuscule', 'big', 'enceinte', 'expectant', 'gravid', 'large', 'heavy', 'with', 'grande', 'importante', 'grande', 'eminente', 'grande', 'grande', 'fuerte', 'grande', 'terrible', 'grande', 'grande', 'importante', 'excelente', 'grande', 'magnífico']
# Actual Word: good
#
# Predicted Word: lelapero
# Prediction Synonyms:
# ['lelapero', 'siguiente →']
# Actual Word: bien
#
# Predicted Word: trying
# Prediction Synonyms:
# ['trying', 'intentando', 'try', 'seek', 'attempt', 'essay', 'assay', 'test', 'prove', 'try', 'try', 'examine', 'essay', 'judge', 'adjudicate', 'try', 'sample', 'try', 'try', 'taste', 'hear', 'try', 'try', 'try', 'strain', 'stress', 'try', 'render', 'try', 'try', 'nerveracking', 'nervewracking', 'stressful']
# Actual Word: trying
# MATCH FOUND!
#
# Predicted Word: frente
# Prediction Synonyms:
# ['the front', 'frente', 'cabeza', 'primer', 'primera', 'vanguardia', 'presencia']
# Actual Word: vacaciones
#
# Predicted Word: y
# Prediction Synonyms:
# ['and', 'y', 'y']
# Actual Word: lol
#
# Predicted Word: pronunciación
# Prediction Synonyms:
# ['pronunciation', 'pronunciación', 'orthoepy']
# Actual Word: la
#
# Predicted Word: my
# Prediction Synonyms:
# ['my', 'mi']
# Actual Word: me
#
# Predicted Word: bells
# Prediction Synonyms:
# ['bells', 'bélgica', 'bell', 'doorbell', 'bell', 'buzzer', 'bell', 'toll', 'bell', "ship's", 'bell', 'bell', 'campana', 'bell', 'melville', 'alexander', 'bell', 'vanessa', 'vanessa', 'bell', 'alexander', 'alexander', 'chime', 'bell', 'gong', 'bell', 'bell']
# Actual Word: bells
# MATCH FOUND!
#
# Predicted Word: ach
# Prediction Synonyms:
# ['ach', 'aqu']
# Actual Word: and
#
# Predicted Word: together
# Prediction Synonyms:
# ['together', 'juntos', 'unitedly', 'in', 'hombro', 'colectivamente', 'conjuntamente', 'a', 'casi', 'empatados']
# Actual Word: but
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: that's
#
# Predicted Word: nobody
# Prediction Synonyms:
# ['nobody', 'ninguno', 'cipher', 'cypher', 'nonentity']
# Actual Word: it
#
# Predicted Word: 😂😭
# Prediction Synonyms:
# ['😂😭', '😂😂']
# Actual Word: stay
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: ver
#
# Predicted Word: in
# Prediction Synonyms:
# ['in', 'en', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward', 'tuerca']
# Actual Word: during
#
# Predicted Word: del
# Prediction Synonyms:
# ['of', 'del']
# Actual Word:
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: thatd
#
# Predicted Word: perfect
# Prediction Synonyms:
# ['perfect', 'perfecto', 'perfective', 'perfective', 'perfect', 'hone', 'arrant', 'complete', 'consummate', 'doubledyed', 'everlasting', 'gross', 'pure', 'sodding', 'stark', 'staring', 'thoroughgoing', 'utter', 'unadulterated', 'absoluto', 'completo', 'puro', 'total', 'absoluto', 'completo', 'total', 'exacto', 'preciso']
# Actual Word: the
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: to
#
# Predicted Word: on
# Prediction Synonyms:
# ['on', 'en', 'along', 'tuerca']
# Actual Word: on
# MATCH FOUND!
#
# Predicted Word: se
# Prediction Synonyms:
# ['by', 'si se', 'past', 'aside', 'away']
# Actual Word: vuelvo
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: lmao
#
# Predicted Word: possible
# Prediction Synonyms:
# ['possible', 'posible', 'potential', 'potencial', 'probable']
# Actual Word: t
#
# Predicted Word: it
# Prediction Synonyms:
# ['it', 'el', 'information', 'it']
# Actual Word: a
#
# Predicted Word: place
# Prediction Synonyms:
# ['place', 'lugar', 'topographic', 'spot', 'property', 'stead', 'position', 'lieu', 'shoes', 'home', 'position', 'post', 'berth', 'office', 'spot', 'billet', 'situation', 'position', 'station', 'seat', 'plaza', 'piazza', 'position', 'space', 'blank', 'put', 'set', 'pose', 'position', 'lay', 'rate', 'rank', 'range', 'order', 'grade', 'locate', 'site', 'come', 'come', 'target', 'aim', 'direct', 'point', 'identify', 'set', 'localize', 'localise', 'put', 'set', 'localize', 'localise', 'invest', 'put', 'commit', 'station', 'post', 'send', 'posición', 'puesto', 'sitio', 'colocación', 'emplazamiento', 'localización', 'posición', 'radicación', 'sitio', 'situación', 'ubicación', 'espacio', 'sitio', 'posición', 'parcela', 'propiedad', 'terreno', 'puesto', 'sitio', 'posición', 'sitio', 'sitio', 'distinción', 'posición', 'prestigio']
# Actual Word: so
#
# Predicted Word: heard
# Prediction Synonyms:
# ['heard', 'escuchado', 'hear', 'learn', 'hear', 'get', 'get', 'pick', 'find', 'get', 'discover', 'see', 'hear', 'try', 'hear', 'listen', 'hear', 'take']
# Actual Word: saw
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: te
#
# Predicted Word: the
# Prediction Synonyms:
# ['the', 'el']
# Actual Word: in
#
# Predicted Word: caja
# Prediction Synonyms:
# ['caja', 'caja', 'caja', 'cubierta']
# Actual Word: pic
#
# Predicted Word: que
# Prediction Synonyms:
# ['that', 'que']
# Actual Word: me
#
# Predicted Word: of
# Prediction Synonyms:
# ['of', 'de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: of
# MATCH FOUND!
#
# Predicted Word: lol
# Prediction Synonyms:
# ['lol', 'lol']
# Actual Word: ala
#
# Predicted Word: que
# Prediction Synonyms:
# ['that', 'que']
# Actual Word: que
# MATCH FOUND!
#
# Predicted Word: year
# Prediction Synonyms:
# ['year', 'año', 'twelvemonth', 'yr', 'class']
# Actual Word: weekend
#
# Predicted Word: the
# Prediction Synonyms:
# ['the', 'el']
# Actual Word: doing
#
# Predicted Word: this
# Prediction Synonyms:
# ['this', 'este']
# Actual Word: it
#
# Predicted Word: con
# Prediction Synonyms:
# ['with', 'con']
# Actual Word: para
#
# Predicted Word: columbia
# Prediction Synonyms:
# ['columbia', 'colombia', 'columbia', 'columbia', 'columbia', 'columbia', 'capital', 'columbia', 'columbia', 'columbia']
# Actual Word: and
#
# Predicted Word: do
# Prediction Synonyms:
# ['do', 'y lo', 'bash', 'brawl', 'doh', 'ut', 'doctor', 'do', 'make', 'perform', 'execute', 'perform', 'fare', 'make', 'come', 'get', 'cause', 'make', 'practice', 'practise', 'exercise', 'suffice', 'answer', 'serve', 'make', 'act', 'behave', 'serve', 'manage', 'dress', 'arrange', 'set', 'coif', 'coiffe', 'coiffure']
# Actual Word: hate
#
# Predicted Word: bellys
# Prediction Synonyms:
# ['bellys', 'bellas', 'abdomen', 'venter', 'stomach', 'belly', 'belly', 'paunch', 'belly', 'belly', 'belly', 'belly', 'belly']
# Actual Word: de
#
# Predicted Word: te
# Prediction Synonyms:
# ['te', 'te', 'tellurium', 'te', 'atomic', 'ti', 'si']
# Actual Word: agarre
#
# Predicted Word: be
# Prediction Synonyms:
# ['be', 'ser', 'beryllium', 'be', 'glucinium', 'atomic', 'exist', 'equal', 'constitute', 'represent', 'make', 'comprise', 'follow', 'embody', 'personify', 'live', 'cost', 'organismo', 'ser', 'organismo', 'ser', 'constituir', 'representar', 'equivaler', 'significar']
# Actual Word: be
# MATCH FOUND!
#
# Predicted Word: haha
# Prediction Synonyms:
# ['haha', 'hahaha']
# Actual Word: se
#
# Predicted Word: over…
# Prediction Synonyms:
# ['over…', 'sobre']
# Actual Word: on
#
# Predicted Word: the
# Prediction Synonyms:
# ['the', 'el']
# Actual Word: the
# MATCH FOUND!
#
# Predicted Word: si
# Prediction Synonyms:
# ['it is', 'si']
# Actual Word: bien
#
# Predicted Word: d
# Prediction Synonyms:
# ['d', 'd', 'vitamin', 'calciferol', 'viosterol', 'ergocalciferol', 'cholecalciferol', 'd', 'five', '500', 'd', 'd', 'five', '500', 'd', 'calciferol', 'colecalciferol', 'ergocalciferol', 'visoterol', 'vitamina']
# Actual Word: los
#
# Predicted Word: asleep
# Prediction Synonyms:
# ['asleep', 'sueño', 'benumbed', 'numb', 'at', 'at', 'deceased', 'departed', 'gone', 'quimera', 'sueño', 'sueño', 'ensueño', 'ilusión', 'utopía', 'ambición', 'aspiración', 'pretensión', 'cabezada', 'siesta']
# Actual Word: asleep
# MATCH FOUND!
#
# Predicted Word: cortito
# Prediction Synonyms:
# ['cuted', 'cortado', 'cut', 'reduce', 'cut', 'cut', 'trim', 'trim', 'trim', 'cut', 'bring', 'swerve', 'sheer', 'curve', 'trend', 'veer', 'slue', 'slew', 'cut', 'cut', 'cut', 'cut', 'cut', 'tailor', 'cut', 'write', 'issue', 'make', 'cut', 'edit', 'cut', 'edit', 'cut', 'skip', 'hack', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'cut', 'burn', 'cut', 'cut', 'cut', 'cut', 'cut', 'switch', 'cut', 'turn', 'turn', 'cut', 'cut', 'cut', 'ignore', 'disregard', 'snub', 'cut', 'cut', 'cut', 'prune', 'rationalize', 'rationalise', 'cut', 'cut', 'cut', 'cut', 'abridge', 'foreshorten', 'abbreviate', 'shorten', 'cut', 'contract', 'reduce', 'dilute', 'thin', 'thin', 'reduce', 'cut', 'cut', 'cut', 'geld', 'cut', 'recortado']
# Actual Word: notadoo
#
# Predicted Word: kasi
# Prediction Synonyms:
# ['by cas', 'casas']
# Actual Word: 3
#
# Predicted Word: que
# Prediction Synonyms:
# ['that', 'que']
# Actual Word: sick
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: ni
#
# Predicted Word: day
# Prediction Synonyms:
# ['day', 'día', 'twentyfour', 'twentyfour', '24hour', 'solar', 'mean', 'daytime', 'daylight', 'sidereal', 'day', 'clarence', 'clarence', 'jornada']
# Actual Word: day
# MATCH FOUND!
#
# Predicted Word: #cyber
# Prediction Synonyms:
# ['#cyber', '#cyber']
# Actual Word: friend
#
# Predicted Word: in
# Prediction Synonyms:
# ['in', 'en', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward', 'tuerca']
# Actual Word: in
# MATCH FOUND!
#
# Predicted Word: little
# Prediction Synonyms:
# ['little', 'pequeño', 'small', 'slight', 'small', 'fiddling', 'footling', 'lilliputian', 'niggling', 'piddling', 'piffling', 'petty', 'picayune', 'trivial', 'small', 'short', 'minuscule', 'small', 'insignificante', 'trivial', 'menudo', 'insignificante', 'modesto', 'escaso', 'humilde', 'modesto', 'sencillo', 'menor', 'pequeña']
# Actual Word: serious
#
# Predicted Word: nana
# Prediction Synonyms:
# ['nana', 'nana', 'abue', 'abuela', 'abuelita', 'tata']
# Actual Word: padrino
#
# Predicted Word: dorar
# Prediction Synonyms:
# ['golded', 'dolores']
# Actual Word: a
#
# Predicted Word: jos
# Prediction Synonyms:
# ['if', 'si']
# Actual Word: signal
#
# Predicted Word: no
# Prediction Synonyms:
# ['no', 'no', 'nobelium', 'no', 'atomic', 'no']
# Actual Word: we
#
# Predicted Word: to
# Prediction Synonyms:
# ['to', 'para']
# Actual Word: to
# MATCH FOUND!
#
# Predicted Word: in
# Prediction Synonyms:
# ['in', 'en', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward', 'tuerca']
# Actual Word: in
# MATCH FOUND!
#
# Predicted Word: using
# Prediction Synonyms:
# ['using', 'uso de', 'exploitation', 'victimization', 'victimisation', 'use', 'utilize', 'utilise', 'apply', 'employ', 'use', 'habituate', 'use', 'expend', 'use', 'practice', 'apply', 'use', 'use']
# Actual Word: on
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: >
#
# Predicted Word: of
# Prediction Synonyms:
# ['of', 'de', 'de', 'delaware', 'estado', 'primer']
# Actual Word: from
#
# Predicted Word: in
# Prediction Synonyms:
# ['in', 'en', 'inch', 'indium', 'in', 'atomic', 'indiana', 'hoosier', 'in', 'inwards', 'inward', 'tuerca']
# Actual Word: in
# MATCH FOUND!
#
# Predicted Word: pool
# Prediction Synonyms:
# ['pool', 'piscina', 'pond', 'consortium', 'syndicate', 'puddle', 'kitty', 'puddle', 'pocket', 'natatorio', 'pileta']
# Actual Word: super
#
# Predicted Word: a
# Prediction Synonyms:
# ['a', 'a', 'angstrom', 'angstrom', 'a', 'vitamin', 'antiophthalmic', 'axerophthol', 'a', 'deoxyadenosine', 'a', 'adenine', 'a', 'ampere', 'amp', 'a', 'a', 'a', 'type', 'group', 'a']
# Actual Word: everything
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: useless
#
# Predicted Word: lng
# Prediction Synonyms:
# ['lng', 'lng']
# Actual Word: el
#
# Predicted Word:
# Prediction Synonyms:
# ['', '']
# Actual Word: podido
#
# Predicted Word: aside
# Prediction Synonyms:
# ['aside', 'aside', 'digression', 'excursus', 'divagation', 'parenthesis', 'away', 'apart', 'away', 'apart', 'by', 'away']
# Actual Word: aside
# MATCH FOUND!

# %%
print("Standard Metric Scores:")

for score in scores:
  print(score)
print()
# Out:
# Standard Metric Scores:
# 0.21739130434782608
# 0.12987012987012986
# 0.1839080459770115

# %%
print("Synonym Metric Scores:")

for synonym_score in synonym_scores:
  print(synonym_score)
print()
# Out:
# Synonym Metric Scores:
# 0.22826086956521738
# 0.12987012987012986
# 0.1839080459770115
